# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
data = r'/content/gdrive/MyDrive/skripsi/data-cluster4-clean.csv'
data = pd.read_csv(data)

# %%
data
# Out:
#      Unnamed: 0                PK_check                PERFORMANCE_check  \
# 0             0  PK>=0.9385167116294848  PERFORMANCE>=0.9137402574656274
# 1             1  PK>=0.9385167116294848  PERFORMANCE>=0.9137402574656274
# 2             2  PK>=0.9385167116294848  PERFORMANCE>=0.9137402574656274
# 3             3  PK>=0.9385167116294848  PERFORMANCE>=0.9137402574656274
# 4             4  PK>=0.9385167116294848  PERFORMANCE>=0.9137402574656274
# ..          ...                     ...                              ...
# 596         596  PK>=0.9385167116294848  PERFORMANCE>=0.9137402574656274
# 597         597  PK>=0.9385167116294848  PERFORMANCE>=0.9137402574656274
# 598         598   PK<0.9385167116294848   PERFORMANCE<0.9137402574656274
# 599         599   PK<0.9385167116294848   PERFORMANCE<0.9137402574656274
# 600         600   PK<0.9385167116294848   PERFORMANCE<0.9137402574656274
#
#                    COMPETENCY_check                LEARNING_POINT_check  \
# 0    COMPETENCY>=0.5787413134971126  LEARNING_POINT>=0.9771381031613977
# 1    COMPETENCY>=0.5787413134971126  LEARNING_POINT>=0.9771381031613977
# 2    COMPETENCY>=0.5787413134971126  LEARNING_POINT>=0.9771381031613977
# 3    COMPETENCY>=0.5787413134971126  LEARNING_POINT>=0.9771381031613977
# 4     COMPETENCY<0.5787413134971126  LEARNING_POINT>=0.9771381031613977
# ..                              ...                                 ...
# 596  COMPETENCY>=0.5787413134971126  LEARNING_POINT>=0.9771381031613977
# 597  COMPETENCY>=0.5787413134971126  LEARNING_POINT>=0.9771381031613977
# 598  COMPETENCY>=0.5787413134971126  LEARNING_POINT>=0.9771381031613977
# 599  COMPETENCY>=0.5787413134971126  LEARNING_POINT>=0.9771381031613977
# 600   COMPETENCY<0.5787413134971126  LEARNING_POINT>=0.9771381031613977
#
#                    Kerja_Ibadah_check                Apresiasi_check  \
# 0    Kerja_Ibadah>=0.9258643002403404  Apresiasi>=0.8972115439784266
# 1    Kerja_Ibadah>=0.9258643002403404  Apresiasi>=0.8972115439784266
# 2    Kerja_Ibadah>=0.9258643002403404   Apresiasi<0.8972115439784266
# 3    Kerja_Ibadah>=0.9258643002403404  Apresiasi>=0.8972115439784266
# 4    Kerja_Ibadah>=0.9258643002403404  Apresiasi>=0.8972115439784266
# ..                                ...                            ...
# 596  Kerja_Ibadah>=0.9258643002403404  Apresiasi>=0.8972115439784266
# 597  Kerja_Ibadah>=0.9258643002403404  Apresiasi>=0.8972115439784266
# 598  Kerja_Ibadah>=0.9258643002403404  Apresiasi>=0.8972115439784266
# 599   Kerja_Ibadah<0.9258643002403404   Apresiasi<0.8972115439784266
# 600   Kerja_Ibadah<0.9258643002403404   Apresiasi<0.8972115439784266
#
#                    Lebih_cepat_check                Aktif_bersama_check
# 0    Lebih_cepat>=0.8653393769005681  Aktif_bersama>=0.8921737580223437
# 1    Lebih_cepat>=0.8653393769005681  Aktif_bersama>=0.8921737580223437
# 2     Lebih_cepat<0.8653393769005681   Aktif_bersama<0.8921737580223437
# 3    Lebih_cepat>=0.8653393769005681  Aktif_bersama>=0.8921737580223437
# 4    Lebih_cepat>=0.8653393769005681   Aktif_bersama<0.8921737580223437
# ..                               ...                                ...
# 596  Lebih_cepat>=0.8653393769005681  Aktif_bersama>=0.8921737580223437
# 597  Lebih_cepat>=0.8653393769005681  Aktif_bersama>=0.8921737580223437
# 598  Lebih_cepat>=0.8653393769005681  Aktif_bersama>=0.8921737580223437
# 599   Lebih_cepat<0.8653393769005681   Aktif_bersama<0.8921737580223437
# 600   Lebih_cepat<0.8653393769005681   Aktif_bersama<0.8921737580223437
#
# [601 rows x 9 columns]

# %%
records = []
for i in range(0, 601):
    records.append([str(data.values[i,j]) for j in range(0, 9)])

# %%
records
# Out:
# [['0',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['1',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['2',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['3',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['4',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['5',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['6',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['7',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['8',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['9',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['10',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['11',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['12',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['13',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['14',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['15',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['16',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['17',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['18',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['19',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['20',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['21',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['22',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['23',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['24',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['25',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['26',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['27',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['28',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['29',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['30',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['31',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['32',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['33',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['34',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['35',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['36',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['37',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['38',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['39',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['40',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['41',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['42',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['43',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['44',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['45',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['46',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['47',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['48',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['49',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT<0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['50',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['51',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['52',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['53',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['54',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['55',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['56',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['57',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['58',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['59',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['60',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['61',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['62',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['63',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['64',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['65',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['66',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['67',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['68',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['69',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['70',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['71',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['72',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['73',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['74',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['75',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['76',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['77',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['78',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['79',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['80',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['81',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['82',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['83',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['84',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['85',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['86',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['87',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['88',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['89',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['90',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['91',
#   'PK<0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['92',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['93',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['94',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['95',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['96',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['97',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['98',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['99',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['100',
#   'PK<0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['101',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['102',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['103',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['104',
#   'PK<0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['105',
#   'PK<0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['106',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['107',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['108',
#   'PK<0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['109',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['110',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['111',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['112',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['113',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['114',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['115',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['116',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['117',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['118',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['119',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['120',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['121',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['122',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['123',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['124',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['125',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['126',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['127',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['128',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['129',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['130',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['131',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['132',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['133',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['134',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['135',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['136',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['137',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['138',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['139',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['140',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['141',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['142',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['143',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['144',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['145',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['146',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['147',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['148',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['149',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['150',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['151',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['152',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['153',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['154',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['155',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['156',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['157',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['158',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['159',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['160',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['161',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
# ...
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['548',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['549',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT<0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['550',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT<0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['551',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['552',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['553',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['554',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['555',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['556',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['557',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['558',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['559',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['560',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['561',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['562',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['563',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['564',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['565',
#   'PK<0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['566',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['567',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['568',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['569',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT<0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['570',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['571',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['572',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['573',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['574',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['575',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['576',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['577',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['578',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['579',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['580',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['581',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['582',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT<0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['583',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['584',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['585',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['586',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['587',
#   'PK<0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['588',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['589',
#   'PK<0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['590',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['591',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT<0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['592',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['593',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['594',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT<0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['595',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['596',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['597',
#   'PK>=0.9385167116294848',
#   'PERFORMANCE>=0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['598',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah>=0.9258643002403404',
#   'Apresiasi>=0.8972115439784266',
#   'Lebih_cepat>=0.8653393769005681',
#   'Aktif_bersama>=0.8921737580223437'],
#  ['599',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY>=0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437'],
#  ['600',
#   'PK<0.9385167116294848',
#   'PERFORMANCE<0.9137402574656274',
#   'COMPETENCY<0.5787413134971126',
#   'LEARNING_POINT>=0.9771381031613977',
#   'Kerja_Ibadah<0.9258643002403404',
#   'Apresiasi<0.8972115439784266',
#   'Lebih_cepat<0.8653393769005681',
#   'Aktif_bersama<0.8921737580223437']]

# %%
# !pip install apyori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: apyori in /usr/local/lib/python3.7/dist-packages (1.1.2)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from apyori import apriori
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-b85f7ee6d11f> in <module>
#       2 import matplotlib.pyplot as plt
#       3 import pandas as pd
# ----> 4 from apyori import apriori
#
# ModuleNotFoundError: No module named 'apyori'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
association_rules = apriori(records, min_support=0.4, min_confidence=0.9)

# %%
association_results = list(association_rules)

# %%
print(len(association_results))
# Out:
# 15

# %%
print(association_results[0])
# Out:
# RelationRecord(items=frozenset({'LEARNING_POINT>=0.9771381031613977', 'Apresiasi<0.8972115439784266'}), support=0.36772046589018303, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.8972115439784266'}), items_add=frozenset({'LEARNING_POINT>=0.9771381031613977'}), confidence=0.9020408163265305, lift=1.0425510204081632)])

# %%
for item in association_results:

    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    #second index of the inner list
    print("Support: " + str(item[1]))

    #third index of the list located at 0th
    #of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: LEARNING_POINT>=0.9771381031613977 -> Apresiasi<0.8972115439784266
# Support: 0.36772046589018303
# Confidence: 0.9020408163265305
# Lift: 1.0425510204081632
# =====================================
# Rule: COMPETENCY>=0.5787413134971126 -> LEARNING_POINT>=0.9771381031613977
# Support: 0.40765391014975044
# Confidence: 0.9007352941176472
# Lift: 1.04104213800905
# =====================================
# Rule: LEARNING_POINT>=0.9771381031613977 -> PERFORMANCE>=0.9137402574656274
# Support: 0.6056572379367721
# Confidence: 0.9077306733167083
# Lift: 1.049127182044888
# =====================================
# Rule: LEARNING_POINT>=0.9771381031613977 -> PK>=0.9385167116294848
# Support: 0.6306156405990017
# Confidence: 0.9045346062052505
# Lift: 1.0454332660179915
# =====================================
# Rule: PK>=0.9385167116294848 -> PERFORMANCE>=0.9137402574656274
# Support: 0.6256239600665557
# Confidence: 0.9376558603491272
# Lift: 1.3449431314315643
# =====================================
# Rule: COMPETENCY>=0.5787413134971126 -> Aktif_bersama>=0.8921737580223437
# Support: 0.3011647254575707
# Confidence: 0.9095477386934674
# Lift: 1.3332638803774974
# =====================================
# Rule: Kerja_Ibadah>=0.9258643002403404 -> Aktif_bersama>=0.8921737580223437
# Support: 0.43594009983361065
# Confidence: 0.9225352112676056
# Lift: 1.3523016145654416
# =====================================
# Rule: Aktif_bersama>=0.8921737580223437 -> Apresiasi>=0.8972115439784266
# Support: 0.46422628951747086
# Confidence: 0.9299999999999999
# Lift: 1.3632439024390244
# =====================================
# Rule: Aktif_bersama>=0.8921737580223437 -> Apresiasi>=0.8972115439784266
# Support: 0.4043261231281198
# Confidence: 0.9033457249070631
# Lift: 1.3241726357784023
# =====================================
# Rule: PK>=0.9385167116294848 -> Aktif_bersama>=0.8921737580223437
# Support: 0.3777038269550749
# Confidence: 0.9007936507936507
# Lift: 1.3204316686024002
# =====================================
# Rule: Kerja_Ibadah>=0.9258643002403404 -> Aktif_bersama>=0.8921737580223437
# Support: 0.4459234608985025
# Confidence: 0.9209621993127147
# Lift: 1.3499958092364428
# =====================================
# Rule: PK>=0.9385167116294848 -> Aktif_bersama>=0.8921737580223437
# Support: 0.46755407653910147
# Confidence: 0.9304635761589404
# Lift: 1.3346267524380027
# =====================================
# Rule: PK>=0.9385167116294848 -> Apresiasi>=0.8972115439784266
# Support: 0.41264559068219636
# Confidence: 0.9219330855018588
# Lift: 1.322390893524146
# =====================================
# Rule: COMPETENCY<0.5787413134971126 -> PK>=0.9385167116294848
# Support: 0.30948419301164726
# Confidence: 0.9489795918367347
# Lift: 1.3611855243290634
# =====================================
# Rule: COMPETENCY>=0.5787413134971126 -> LEARNING_POINT>=0.9771381031613977
# Support: 0.31114808652246256
# Confidence: 0.9121951219512195
# Lift: 1.0542870544090057
# =====================================
# Rule: COMPETENCY>=0.5787413134971126 -> LEARNING_POINT>=0.9771381031613977
# Support: 0.30282861896838603
# Confidence: 0.9145728643216081
# Lift: 1.057035175879397
# =====================================
# Rule: COMPETENCY>=0.5787413134971126 -> PK>=0.9385167116294848
# Support: 0.3161397670549085
# Confidence: 0.926829268292683
# Lift: 1.3294138191978577
# =====================================
# Rule: Kerja_Ibadah>=0.9258643002403404 -> PK>=0.9385167116294848
# Support: 0.4442595673876872
# Confidence: 0.9368421052631578
# Lift: 1.3437759075493025
# =====================================
# Rule: LEARNING_POINT>=0.9771381031613977 -> PK>=0.9385167116294848
# Support: 0.5707154742096506
# Confidence: 0.9423076923076924
# Lift: 1.3516155682026805
# =====================================
# Rule: PK>=0.9385167116294848 -> Lebih_cepat>=0.8653393769005681
# Support: 0.4259567387687188
# Confidence: 0.927536231884058
# Lift: 1.3304278648265366
# =====================================
# Rule: Kerja_Ibadah>=0.9258643002403404 -> LEARNING_POINT>=0.9771381031613977
# Support: 0.3577371048252912
# Confidence: 0.9110169491525425
# Lift: 1.335417527904093
# =====================================
# Rule: Kerja_Ibadah>=0.9258643002403404 -> Aktif_bersama>=0.8921737580223437
# Support: 0.40099833610648916
# Confidence: 0.9198473282442747
# Lift: 1.548538499369213
# =====================================
# Rule: Kerja_Ibadah>=0.9258643002403404 -> Aktif_bersama>=0.8921737580223437
# Support: 0.33777038269550747
# Confidence: 0.918552036199095
# Lift: 1.3464628628186734
# =====================================
# Rule: Kerja_Ibadah>=0.9258643002403404 -> PK>=0.9385167116294848
# Support: 0.3161397670549085
# Confidence: 0.9178743961352657
# Lift: 1.3454695416519382
# =====================================
# Rule: LEARNING_POINT>=0.9771381031613977 -> Aktif_bersama>=0.8921737580223437
# Support: 0.3793677204658902
# Confidence: 0.923076923076923
# Lift: 1.3530956848030018
# =====================================
# Rule: Aktif_bersama>=0.8921737580223437 -> Apresiasi>=0.8972115439784266
# Support: 0.36605657237936773
# Confidence: 0.9053497942386832
# Lift: 1.52413228665952
# =====================================
# Rule: PK>=0.9385167116294848 -> Aktif_bersama>=0.8921737580223437
# Support: 0.33777038269550747
# Confidence: 0.9311926605504586
# Lift: 1.3649921682703063
# =====================================
# Rule: PK>=0.9385167116294848 -> Aktif_bersama>=0.8921737580223437
# Support: 0.37271214642262895
# Confidence: 0.9218106995884774
# Lift: 1.322215347142422
# =====================================
# Rule: Kerja_Ibadah>=0.9258643002403404 -> LEARNING_POINT>=0.9771381031613977
# Support: 0.36772046589018303
# Confidence: 0.9094650205761318
# Lift: 1.3331426277225737
# =====================================
# Rule: Kerja_Ibadah>=0.9258643002403404 -> Aktif_bersama>=0.8921737580223437
# Support: 0.3427620632279534
# Confidence: 0.911504424778761
# Lift: 1.3361320958342326
# =====================================
# Rule: Kerja_Ibadah>=0.9258643002403404 -> PK>=0.9385167116294848
# Support: 0.3211314475873544
# Confidence: 0.9061032863849765
# Lift: 1.3282148173594412
# =====================================
# Rule: Kerja_Ibadah>=0.9258643002403404 -> PK>=0.9385167116294848
# Support: 0.37603993344425957
# Confidence: 0.9338842975206613
# Lift: 1.339533324128681
# =====================================
# Rule: LEARNING_POINT>=0.9771381031613977 -> Aktif_bersama>=0.8921737580223437
# Support: 0.4176372712146423
# Confidence: 0.9330855018587361
# Lift: 1.338387557558712
# =====================================
# Rule: PK>=0.9385167116294848 -> Aktif_bersama>=0.8921737580223437
# Support: 0.37437603993344426
# Confidence: 0.925925925925926
# Lift: 1.3281180942278794
# =====================================
# Rule: Kerja_Ibadah>=0.9258643002403404 -> Apresiasi>=0.8972115439784266
# Support: 0.33444259567387685
# Confidence: 0.9095022624434388
# Lift: 1.5311228563823718
# =====================================
# Rule: Kerja_Ibadah>=0.9258643002403404 -> PK>=0.9385167116294848
# Support: 0.31114808652246256
# Confidence: 0.9033816425120772
# Lift: 1.520818955601564
# =====================================
# Rule: Kerja_Ibadah>=0.9258643002403404 -> PK>=0.9385167116294848
# Support: 0.3410981697171381
# Confidence: 0.927601809954751
# Lift: 1.3305219278825904
# =====================================
# Rule: LEARNING_POINT>=0.9771381031613977 -> Apresiasi>=0.8972115439784266
# Support: 0.36772046589018303
# Confidence: 0.9246861924686193
# Lift: 1.3263398607962773
# =====================================
# Rule: PK>=0.9385167116294848 -> Apresiasi>=0.8972115439784266
# Support: 0.3610648918469218
# Confidence: 0.9156118143459916
# Lift: 1.3133238673554675
# =====================================
# Rule: Kerja_Ibadah>=0.9258643002403404 -> LEARNING_POINT>=0.9771381031613977
# Support: 0.39933444259567386
# Confidence: 0.9448818897637794
# Lift: 1.3553079134797885
# =====================================
# Rule: Kerja_Ibadah>=0.9258643002403404 -> PK>=0.9385167116294848
# Support: 0.35108153078202997
# Confidence: 0.9336283185840708
# Lift: 1.33916615625066
# =====================================
# Rule: PK>=0.9385167116294848 -> LEARNING_POINT>=0.9771381031613977
# Support: 0.3793677204658902
# Confidence: 0.9306122448979591
# Lift: 1.3348399980517265
# =====================================
# Rule: Kerja_Ibadah>=0.9258643002403404 -> LEARNING_POINT>=0.9771381031613977
# Support: 0.3261231281198003
# Confidence: 0.9116279069767441
# Lift: 1.5347013223894208
# =====================================
# Rule: PERFORMANCE>=0.9137402574656274 -> Kerja_Ibadah>=0.9258643002403404
# Support: 0.3161397670549085
# Confidence: 0.935960591133005
# Lift: 1.575664748658084
# =====================================
# Rule: PK>=0.9385167116294848 -> PERFORMANCE>=0.9137402574656274
# Support: 0.31281198003327787
# Confidence: 0.9082125603864734
# Lift: 1.80740314169626
# =====================================
# Rule: PERFORMANCE>=0.9137402574656274 -> LEARNING_POINT>=0.9771381031613977
# Support: 0.3161397670549085
# Confidence: 0.9178743961352657
# Lift: 1.3454695416519382
# =====================================
# Rule: PK>=0.9385167116294848 -> PERFORMANCE>=0.9137402574656274
# Support: 0.3277870216306156
# Confidence: 0.9248826291079811
# Lift: 1.3266216231357915
# =====================================
# Rule: PK>=0.9385167116294848 -> PERFORMANCE>=0.9137402574656274
# Support: 0.33610648918469216
# Confidence: 0.9266055045871558
# Lift: 1.8440063187313929
# =====================================
# Rule: PK>=0.9385167116294848 -> PERFORMANCE>=0.9137402574656274
# Support: 0.33277870216306155
# Confidence: 0.9389671361502346
# Lift: 1.346823982878976
# =====================================
# Rule: PK>=0.9385167116294848 -> PERFORMANCE>=0.9137402574656274
# Support: 0.3194675540765391
# Confidence: 0.9014084507042253
# Lift: 1.793862512825296
# =====================================
# Rule: PK>=0.9385167116294848 -> PERFORMANCE>=0.9137402574656274
# Support: 0.3277870216306156
# Confidence: 0.9292452830188679
# Lift: 1.3328792723015264
# =====================================
# Rule: PK>=0.9385167116294848 -> PERFORMANCE>=0.9137402574656274
# Support: 0.3011647254575707
# Confidence: 0.9329896907216495
# Lift: 1.3382501291735354
# =====================================
# Rule: PK>=0.9385167116294848 -> PERFORMANCE>=0.9137402574656274
# Support: 0.30948419301164726
# Confidence: 0.9253731343283582
# Lift: 1.3273251879029673
# =====================================
# Rule: PK>=0.9385167116294848 -> PERFORMANCE>=0.9137402574656274
# Support: 0.3161397670549085
# Confidence: 0.9178743961352657
# Lift: 1.3165692412345933
# =====================================
# Rule: PK>=0.9385167116294848 -> PERFORMANCE>=0.9137402574656274
# Support: 0.30948419301164726
# Confidence: 0.9393939393939394
# Lift: 1.3474361755984667
# =====================================

# %%
for i in (association_results):
  print(i)
# Out:
# RelationRecord(items=frozenset({'COMPETENCY>=0.5787413134971126', 'LEARNING_POINT>=0.9771381031613977'}), support=0.40765391014975044, ordered_statistics=[OrderedStatistic(items_base=frozenset({'COMPETENCY>=0.5787413134971126'}), items_add=frozenset({'LEARNING_POINT>=0.9771381031613977'}), confidence=0.9007352941176472, lift=1.04104213800905)])
# RelationRecord(items=frozenset({'LEARNING_POINT>=0.9771381031613977', 'PERFORMANCE>=0.9137402574656274'}), support=0.6056572379367721, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PERFORMANCE>=0.9137402574656274'}), items_add=frozenset({'LEARNING_POINT>=0.9771381031613977'}), confidence=0.9077306733167083, lift=1.049127182044888)])
# RelationRecord(items=frozenset({'LEARNING_POINT>=0.9771381031613977', 'PK>=0.9385167116294848'}), support=0.6306156405990017, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PK>=0.9385167116294848'}), items_add=frozenset({'LEARNING_POINT>=0.9771381031613977'}), confidence=0.9045346062052505, lift=1.0454332660179915)])
# RelationRecord(items=frozenset({'PK>=0.9385167116294848', 'PERFORMANCE>=0.9137402574656274'}), support=0.6256239600665557, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PERFORMANCE>=0.9137402574656274'}), items_add=frozenset({'PK>=0.9385167116294848'}), confidence=0.9376558603491272, lift=1.3449431314315643)])
# RelationRecord(items=frozenset({'Kerja_Ibadah>=0.9258643002403404', 'Aktif_bersama>=0.8921737580223437', 'Apresiasi>=0.8972115439784266'}), support=0.43594009983361065, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kerja_Ibadah>=0.9258643002403404', 'Apresiasi>=0.8972115439784266'}), items_add=frozenset({'Aktif_bersama>=0.8921737580223437'}), confidence=0.9225352112676056, lift=1.3523016145654416)])
# RelationRecord(items=frozenset({'Aktif_bersama>=0.8921737580223437', 'Apresiasi>=0.8972115439784266', 'Lebih_cepat>=0.8653393769005681'}), support=0.46422628951747086, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi>=0.8972115439784266', 'Lebih_cepat>=0.8653393769005681'}), items_add=frozenset({'Aktif_bersama>=0.8921737580223437'}), confidence=0.9299999999999999, lift=1.3632439024390244)])
# RelationRecord(items=frozenset({'Aktif_bersama>=0.8921737580223437', 'Apresiasi>=0.8972115439784266', 'PERFORMANCE>=0.9137402574656274'}), support=0.4043261231281198, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi>=0.8972115439784266', 'PERFORMANCE>=0.9137402574656274'}), items_add=frozenset({'Aktif_bersama>=0.8921737580223437'}), confidence=0.9033457249070631, lift=1.3241726357784023)])
# RelationRecord(items=frozenset({'Kerja_Ibadah>=0.9258643002403404', 'Aktif_bersama>=0.8921737580223437', 'Lebih_cepat>=0.8653393769005681'}), support=0.4459234608985025, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kerja_Ibadah>=0.9258643002403404', 'Lebih_cepat>=0.8653393769005681'}), items_add=frozenset({'Aktif_bersama>=0.8921737580223437'}), confidence=0.9209621993127147, lift=1.3499958092364428)])
# RelationRecord(items=frozenset({'PK>=0.9385167116294848', 'Aktif_bersama>=0.8921737580223437', 'PERFORMANCE>=0.9137402574656274'}), support=0.46755407653910147, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama>=0.8921737580223437', 'PERFORMANCE>=0.9137402574656274'}), items_add=frozenset({'PK>=0.9385167116294848'}), confidence=0.9304635761589404, lift=1.3346267524380027), OrderedStatistic(items_base=frozenset({'PK>=0.9385167116294848', 'Aktif_bersama>=0.8921737580223437'}), items_add=frozenset({'PERFORMANCE>=0.9137402574656274'}), confidence=0.9689655172413792, lift=1.4522400894315934)])
# RelationRecord(items=frozenset({'PK>=0.9385167116294848', 'Apresiasi>=0.8972115439784266', 'PERFORMANCE>=0.9137402574656274'}), support=0.41264559068219636, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi>=0.8972115439784266', 'PERFORMANCE>=0.9137402574656274'}), items_add=frozenset({'PK>=0.9385167116294848'}), confidence=0.9219330855018588, lift=1.322390893524146), OrderedStatistic(items_base=frozenset({'PK>=0.9385167116294848', 'Apresiasi>=0.8972115439784266'}), items_add=frozenset({'PERFORMANCE>=0.9137402574656274'}), confidence=0.9841269841269842, lift=1.4749633851878243)])
# RelationRecord(items=frozenset({'Kerja_Ibadah>=0.9258643002403404', 'PK>=0.9385167116294848', 'PERFORMANCE>=0.9137402574656274'}), support=0.4442595673876872, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kerja_Ibadah>=0.9258643002403404', 'PERFORMANCE>=0.9137402574656274'}), items_add=frozenset({'PK>=0.9385167116294848'}), confidence=0.9368421052631578, lift=1.3437759075493025), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah>=0.9258643002403404', 'PK>=0.9385167116294848'}), items_add=frozenset({'PERFORMANCE>=0.9137402574656274'}), confidence=0.9709090909090909, lift=1.4551530265245978)])
# RelationRecord(items=frozenset({'LEARNING_POINT>=0.9771381031613977', 'PK>=0.9385167116294848', 'PERFORMANCE>=0.9137402574656274'}), support=0.5707154742096506, ordered_statistics=[OrderedStatistic(items_base=frozenset({'LEARNING_POINT>=0.9771381031613977', 'PERFORMANCE>=0.9137402574656274'}), items_add=frozenset({'PK>=0.9385167116294848'}), confidence=0.9423076923076924, lift=1.3516155682026805), OrderedStatistic(items_base=frozenset({'LEARNING_POINT>=0.9771381031613977', 'PK>=0.9385167116294848'}), items_add=frozenset({'PERFORMANCE>=0.9137402574656274'}), confidence=0.9050131926121373, lift=1.356391343540884), OrderedStatistic(items_base=frozenset({'PK>=0.9385167116294848', 'PERFORMANCE>=0.9137402574656274'}), items_add=frozenset({'LEARNING_POINT>=0.9771381031613977'}), confidence=0.9122340425531915, lift=1.054332037643208)])
# RelationRecord(items=frozenset({'PK>=0.9385167116294848', 'Lebih_cepat>=0.8653393769005681', 'PERFORMANCE>=0.9137402574656274'}), support=0.4259567387687188, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Lebih_cepat>=0.8653393769005681', 'PERFORMANCE>=0.9137402574656274'}), items_add=frozenset({'PK>=0.9385167116294848'}), confidence=0.927536231884058, lift=1.3304278648265366), OrderedStatistic(items_base=frozenset({'PK>=0.9385167116294848', 'Lebih_cepat>=0.8653393769005681'}), items_add=frozenset({'PERFORMANCE>=0.9137402574656274'}), confidence=0.9808429118773947, lift=1.470041371666619)])
# RelationRecord(items=frozenset({'Kerja_Ibadah>=0.9258643002403404', 'Aktif_bersama>=0.8921737580223437', 'Apresiasi>=0.8972115439784266', 'Lebih_cepat>=0.8653393769005681'}), support=0.40099833610648916, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kerja_Ibadah>=0.9258643002403404', 'Aktif_bersama>=0.8921737580223437', 'Apresiasi>=0.8972115439784266'}), items_add=frozenset({'Lebih_cepat>=0.8653393769005681'}), confidence=0.9198473282442747, lift=1.548538499369213), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah>=0.9258643002403404', 'Apresiasi>=0.8972115439784266', 'Lebih_cepat>=0.8653393769005681'}), items_add=frozenset({'Aktif_bersama>=0.8921737580223437'}), confidence=0.9488188976377951, lift=1.390829652391012)])
# RelationRecord(items=frozenset({'LEARNING_POINT>=0.9771381031613977', 'Aktif_bersama>=0.8921737580223437', 'PK>=0.9385167116294848', 'PERFORMANCE>=0.9137402574656274'}), support=0.4176372712146423, ordered_statistics=[OrderedStatistic(items_base=frozenset({'LEARNING_POINT>=0.9771381031613977', 'Aktif_bersama>=0.8921737580223437', 'PERFORMANCE>=0.9137402574656274'}), items_add=frozenset({'PK>=0.9385167116294848'}), confidence=0.9330855018587361, lift=1.338387557558712), OrderedStatistic(items_base=frozenset({'LEARNING_POINT>=0.9771381031613977', 'Aktif_bersama>=0.8921737580223437', 'PK>=0.9385167116294848'}), items_add=frozenset({'PERFORMANCE>=0.9137402574656274'}), confidence=0.9728682170542636, lift=1.458089272941677)])

# %% [markdown]
# ## **CLUSTER convert**

# %%
data4 = r'/content/gdrive/MyDrive/skripsi/hasil-cluster4.csv'
cluster4 = pd.read_csv(data4)
data3 = r'/content/gdrive/MyDrive/skripsi/hasil-cluster3.csv'
cluster3 = pd.read_csv(data3)
data2 = r'/content/gdrive/MyDrive/skripsi/hasil-cluster2.csv'
cluster2 = pd.read_csv(data2)
data1 = r'/content/gdrive/MyDrive/skripsi/hasil-cluster1.csv'
cluster1 = pd.read_csv(data1)

# %%
cluster4.rename(columns = {'LEARNING POINT':'LEARNING_POINT',
                           'Kerja Ibadah':'Kerja_Ibadah','Lebih cepat':'Lebih_cepat','Aktif bersama':'Aktif_bersama'}, inplace = True)
cluster3.rename(columns = {'LEARNING POINT':'LEARNING_POINT',
                           'Kerja Ibadah':'Kerja_Ibadah','Lebih cepat':'Lebih_cepat','Aktif bersama':'Aktif_bersama'}, inplace = True)
cluster2.rename(columns = {'LEARNING POINT':'LEARNING_POINT',
                           'Kerja Ibadah':'Kerja_Ibadah','Lebih cepat':'Lebih_cepat','Aktif bersama':'Aktif_bersama'}, inplace = True)
cluster1.rename(columns = {'LEARNING POINT':'LEARNING_POINT',
                           'Kerja Ibadah':'Kerja_Ibadah','Lebih cepat':'Lebih_cepat','Aktif bersama':'Aktif_bersama'}, inplace = True)

# %%
def create_check(cluster,column_name,data):
  result = []
  for value in cluster[column_name]:
    if value >= cluster[column_name].mean():
      string = column_name+">=" + str(cluster[column_name].mean())
      result.append(string) 
      
    else:
      string = column_name+"<" + str(cluster[column_name].mean())
      result.append(string)
  column_new = column_name + "_check"
  cluster[column_new] = result 
  data[column_new]=result

# %%
column_name = cluster4.columns
data4 = pd.DataFrame()

column_name = cluster3.columns
data3 = pd.DataFrame()

column_name = cluster2.columns
data2 = pd.DataFrame()

column_name = cluster1.columns
data1 = pd.DataFrame()

# %%
result = []
for value in cluster4['PERFORMANCE']:
    if value > 0:
      string = "PERFORMANCE"+">" + str(0)
      result.append(string) 
      
    else:
      string = "PERFORMANCE"+"=" + str(0)
      result.append(string)
column_new = "PERFORMANCE" + "_check"
cluster4[column_new] = result 
data4[column_new]=result

# %%
result = []
for value in cluster4['LEARNING_POINT']:
    if value > 0:
      string = "LEARNING_POINT"+">" + str(0)
      result.append(string) 
      
    else:
      string = "LEARNING_POINT"+"=" + str(0)
      result.append(string)
column_new = "LEARNING_POINT" + "_check"
cluster4[column_new] = result 
data4[column_new]=result

# %%
create_check(cluster4,column_name[1],data4)

create_check(cluster4,column_name[3],data4)

create_check(cluster4,column_name[5],data4)
create_check(cluster4,column_name[6],data4)
create_check(cluster4,column_name[7],data4)
create_check(cluster4,column_name[8],data4)

create_check(cluster3,column_name[1],data3)
create_check(cluster3,column_name[2],data3)
create_check(cluster3,column_name[3],data3)
create_check(cluster3,column_name[4],data3)
create_check(cluster3,column_name[5],data3)
create_check(cluster3,column_name[6],data3)
create_check(cluster3,column_name[7],data3)
create_check(cluster3,column_name[8],data3)


create_check(cluster2,column_name[1],data2)
create_check(cluster2,column_name[2],data2)
create_check(cluster2,column_name[3],data2)
create_check(cluster2,column_name[4],data2)
create_check(cluster2,column_name[5],data2)
create_check(cluster2,column_name[6],data2)
create_check(cluster2,column_name[7],data2)
create_check(cluster2,column_name[8],data2)

create_check(cluster1,column_name[1],data1)
create_check(cluster1,column_name[2],data1)
create_check(cluster1,column_name[3],data1)
create_check(cluster1,column_name[4],data1)
create_check(cluster1,column_name[5],data1)
create_check(cluster1,column_name[6],data1)
create_check(cluster1,column_name[7],data1)
create_check(cluster1,column_name[8],data1)

# %%
data3
# Out:
#                    PK_check               PERFORMANCE_check  \
# 0    PK>=0.9069666283884886  PERFORMANCE>=0.872212790039615
# 1     PK<0.9069666283884886   PERFORMANCE<0.872212790039615
# 2     PK<0.9069666283884886  PERFORMANCE>=0.872212790039615
# 3    PK>=0.9069666283884886  PERFORMANCE>=0.872212790039615
# 4     PK<0.9069666283884886  PERFORMANCE>=0.872212790039615
# ..                      ...                             ...
# 553   PK<0.9069666283884886  PERFORMANCE>=0.872212790039615
# 554   PK<0.9069666283884886  PERFORMANCE>=0.872212790039615
# 555   PK<0.9069666283884886   PERFORMANCE<0.872212790039615
# 556   PK<0.9069666283884886   PERFORMANCE<0.872212790039615
# 557   PK<0.9069666283884886  PERFORMANCE>=0.872212790039615
#
#                    COMPETENCY_check                 LEARNING_POINT_check  \
# 0    COMPETENCY>=0.5085388994307399   LEARNING_POINT<0.07743727598566306
# 1     COMPETENCY<0.5085388994307399   LEARNING_POINT<0.07743727598566306
# 2    COMPETENCY>=0.5085388994307399   LEARNING_POINT<0.07743727598566306
# 3    COMPETENCY>=0.5085388994307399   LEARNING_POINT<0.07743727598566306
# 4     COMPETENCY<0.5085388994307399   LEARNING_POINT<0.07743727598566306
# ..                              ...                                  ...
# 553   COMPETENCY<0.5085388994307399   LEARNING_POINT<0.07743727598566306
# 554   COMPETENCY<0.5085388994307399   LEARNING_POINT<0.07743727598566306
# 555  COMPETENCY>=0.5085388994307399   LEARNING_POINT<0.07743727598566306
# 556  COMPETENCY>=0.5085388994307399  LEARNING_POINT>=0.07743727598566306
# 557  COMPETENCY>=0.5085388994307399   LEARNING_POINT<0.07743727598566306
#
#                   Kerja_Ibadah_check                Apresiasi_check  \
# 0    Kerja_Ibadah>=0.903405017921147  Apresiasi>=0.8777654183660857
# 1     Kerja_Ibadah<0.903405017921147   Apresiasi<0.8777654183660857
# 2    Kerja_Ibadah>=0.903405017921147  Apresiasi>=0.8777654183660857
# 3    Kerja_Ibadah>=0.903405017921147   Apresiasi<0.8777654183660857
# 4    Kerja_Ibadah>=0.903405017921147  Apresiasi>=0.8777654183660857
# ..                               ...                            ...
# 553  Kerja_Ibadah>=0.903405017921147  Apresiasi>=0.8777654183660857
# 554  Kerja_Ibadah>=0.903405017921147  Apresiasi>=0.8777654183660857
# 555  Kerja_Ibadah>=0.903405017921147  Apresiasi>=0.8777654183660857
# 556  Kerja_Ibadah>=0.903405017921147  Apresiasi>=0.8777654183660857
# 557   Kerja_Ibadah<0.903405017921147   Apresiasi<0.8777654183660857
#
#                    Lebih_cepat_check                Aktif_bersama_check
# 0    Lebih_cepat>=0.8257013966135212   Aktif_bersama<0.8728558627752174
# 1    Lebih_cepat>=0.8257013966135212  Aktif_bersama>=0.8728558627752174
# 2    Lebih_cepat>=0.8257013966135212  Aktif_bersama>=0.8728558627752174
# 3    Lebih_cepat>=0.8257013966135212  Aktif_bersama>=0.8728558627752174
# 4    Lebih_cepat>=0.8257013966135212  Aktif_bersama>=0.8728558627752174
# ..                               ...                                ...
# 553  Lebih_cepat>=0.8257013966135212  Aktif_bersama>=0.8728558627752174
# 554  Lebih_cepat>=0.8257013966135212  Aktif_bersama>=0.8728558627752174
# 555   Lebih_cepat<0.8257013966135212  Aktif_bersama>=0.8728558627752174
# 556   Lebih_cepat<0.8257013966135212  Aktif_bersama>=0.8728558627752174
# 557  Lebih_cepat>=0.8257013966135212   Aktif_bersama<0.8728558627752174
#
# [558 rows x 8 columns]

# %%
data2
# Out:
#                    PK_check                PERFORMANCE_check  \
# 0    PK>=0.9377574286554868  PERFORMANCE>=0.9174641148325358
# 1    PK>=0.9377574286554868  PERFORMANCE>=0.9174641148325358
# 2    PK>=0.9377574286554868  PERFORMANCE>=0.9174641148325358
# 3    PK>=0.9377574286554868  PERFORMANCE>=0.9174641148325358
# 4    PK>=0.9377574286554868  PERFORMANCE>=0.9174641148325358
# ..                      ...                              ...
# 523  PK>=0.9377574286554868  PERFORMANCE>=0.9174641148325358
# 524  PK>=0.9377574286554868  PERFORMANCE>=0.9174641148325358
# 525  PK>=0.9377574286554868  PERFORMANCE>=0.9174641148325358
# 526   PK<0.9377574286554868   PERFORMANCE<0.9174641148325358
# 527   PK<0.9377574286554868   PERFORMANCE<0.9174641148325358
#
#                    COMPETENCY_check                LEARNING_POINT_check  \
# 0    COMPETENCY>=0.6153631907308377  LEARNING_POINT>=0.9228598484848485
# 1    COMPETENCY>=0.6153631907308377  LEARNING_POINT>=0.9228598484848485
# 2     COMPETENCY<0.6153631907308377  LEARNING_POINT>=0.9228598484848485
# 3    COMPETENCY>=0.6153631907308377  LEARNING_POINT>=0.9228598484848485
# 4     COMPETENCY<0.6153631907308377  LEARNING_POINT>=0.9228598484848485
# ..                              ...                                 ...
# 523  COMPETENCY>=0.6153631907308377  LEARNING_POINT>=0.9228598484848485
# 524   COMPETENCY<0.6153631907308377   LEARNING_POINT<0.9228598484848485
# 525  COMPETENCY>=0.6153631907308377  LEARNING_POINT>=0.9228598484848485
# 526  COMPETENCY>=0.6153631907308377  LEARNING_POINT>=0.9228598484848485
# 527  COMPETENCY>=0.6153631907308377  LEARNING_POINT>=0.9228598484848485
#
#                    Kerja_Ibadah_check                Apresiasi_check  \
# 0    Kerja_Ibadah>=0.9490951178451179  Apresiasi>=0.9514433124346917
# 1    Kerja_Ibadah>=0.9490951178451179  Apresiasi>=0.9514433124346917
# 2    Kerja_Ibadah>=0.9490951178451179   Apresiasi<0.9514433124346917
# 3    Kerja_Ibadah>=0.9490951178451179  Apresiasi>=0.9514433124346917
# 4    Kerja_Ibadah>=0.9490951178451179   Apresiasi<0.9514433124346917
# ..                                ...                            ...
# 523  Kerja_Ibadah>=0.9490951178451179  Apresiasi>=0.9514433124346917
# 524   Kerja_Ibadah<0.9490951178451179  Apresiasi>=0.9514433124346917
# 525  Kerja_Ibadah>=0.9490951178451179  Apresiasi>=0.9514433124346917
# 526  Kerja_Ibadah>=0.9490951178451179  Apresiasi>=0.9514433124346917
# 527   Kerja_Ibadah<0.9490951178451179   Apresiasi<0.9514433124346917
#
#                    Lebih_cepat_check                Aktif_bersama_check
# 0    Lebih_cepat>=0.9192136886102402  Aktif_bersama>=0.9470035173160173
# 1    Lebih_cepat>=0.9192136886102402  Aktif_bersama>=0.9470035173160173
# 2     Lebih_cepat<0.9192136886102402   Aktif_bersama<0.9470035173160173
# 3    Lebih_cepat>=0.9192136886102402  Aktif_bersama>=0.9470035173160173
# 4    Lebih_cepat>=0.9192136886102402   Aktif_bersama<0.9470035173160173
# ..                               ...                                ...
# 523  Lebih_cepat>=0.9192136886102402  Aktif_bersama>=0.9470035173160173
# 524  Lebih_cepat>=0.9192136886102402  Aktif_bersama>=0.9470035173160173
# 525  Lebih_cepat>=0.9192136886102402  Aktif_bersama>=0.9470035173160173
# 526  Lebih_cepat>=0.9192136886102402  Aktif_bersama>=0.9470035173160173
# 527   Lebih_cepat<0.9192136886102402   Aktif_bersama<0.9470035173160173
#
# [528 rows x 8 columns]

# %%
data1
# Out:
#                    PK_check                PERFORMANCE_check  \
# 0    PK>=0.9254869259634284  PERFORMANCE>=0.8809815950920243
# 1    PK>=0.9254869259634284  PERFORMANCE>=0.8809815950920243
# 2    PK>=0.9254869259634284  PERFORMANCE>=0.8809815950920243
# 3    PK>=0.9254869259634284  PERFORMANCE>=0.8809815950920243
# 4    PK>=0.9254869259634284  PERFORMANCE>=0.8809815950920243
# ..                      ...                              ...
# 158  PK>=0.9254869259634284  PERFORMANCE>=0.8809815950920243
# 159  PK>=0.9254869259634284  PERFORMANCE>=0.8809815950920243
# 160   PK<0.9254869259634284   PERFORMANCE<0.8809815950920243
# 161  PK>=0.9254869259634284  PERFORMANCE>=0.8809815950920243
# 162   PK<0.9254869259634284   PERFORMANCE<0.8809815950920243
#
#                     COMPETENCY_check               LEARNING_POINT_check  \
# 0    COMPETENCY>=0.42439552508119793  LEARNING_POINT>=0.886196319018405
# 1     COMPETENCY<0.42439552508119793  LEARNING_POINT>=0.886196319018405
# 2     COMPETENCY<0.42439552508119793  LEARNING_POINT>=0.886196319018405
# 3    COMPETENCY>=0.42439552508119793  LEARNING_POINT>=0.886196319018405
# 4     COMPETENCY<0.42439552508119793  LEARNING_POINT>=0.886196319018405
# ..                               ...                                ...
# 158  COMPETENCY>=0.42439552508119793   LEARNING_POINT<0.886196319018405
# 159   COMPETENCY<0.42439552508119793  LEARNING_POINT>=0.886196319018405
# 160  COMPETENCY>=0.42439552508119793   LEARNING_POINT<0.886196319018405
# 161  COMPETENCY>=0.42439552508119793   LEARNING_POINT<0.886196319018405
# 162   COMPETENCY<0.42439552508119793  LEARNING_POINT>=0.886196319018405
#
#                   Kerja_Ibadah_check                Apresiasi_check  \
# 0    Kerja_Ibadah>=0.823653715064758   Apresiasi<0.6823566744235244
# 1    Kerja_Ibadah>=0.823653715064758   Apresiasi<0.6823566744235244
# 2    Kerja_Ibadah>=0.823653715064758  Apresiasi>=0.6823566744235244
# 3    Kerja_Ibadah>=0.823653715064758   Apresiasi<0.6823566744235244
# 4    Kerja_Ibadah>=0.823653715064758   Apresiasi<0.6823566744235244
# ..                               ...                            ...
# 158  Kerja_Ibadah>=0.823653715064758  Apresiasi>=0.6823566744235244
# 159  Kerja_Ibadah>=0.823653715064758   Apresiasi<0.6823566744235244
# 160  Kerja_Ibadah>=0.823653715064758  Apresiasi>=0.6823566744235244
# 161   Kerja_Ibadah<0.823653715064758   Apresiasi<0.6823566744235244
# 162  Kerja_Ibadah>=0.823653715064758  Apresiasi>=0.6823566744235244
#
#                    Lebih_cepat_check                Aktif_bersama_check
# 0    Lebih_cepat>=0.6432198011423738   Aktif_bersama<0.6640008764241891
# 1     Lebih_cepat<0.6432198011423738   Aktif_bersama<0.6640008764241891
# 2     Lebih_cepat<0.6432198011423738   Aktif_bersama<0.6640008764241891
# 3    Lebih_cepat>=0.6432198011423738  Aktif_bersama>=0.6640008764241891
# 4    Lebih_cepat>=0.6432198011423738   Aktif_bersama<0.6640008764241891
# ..                               ...                                ...
# 158  Lebih_cepat>=0.6432198011423738  Aktif_bersama>=0.6640008764241891
# 159   Lebih_cepat<0.6432198011423738  Aktif_bersama>=0.6640008764241891
# 160  Lebih_cepat>=0.6432198011423738  Aktif_bersama>=0.6640008764241891
# 161   Lebih_cepat<0.6432198011423738   Aktif_bersama<0.6640008764241891
# 162   Lebih_cepat<0.6432198011423738   Aktif_bersama<0.6640008764241891
#
# [163 rows x 8 columns]

# %%
data4
# Out:
#    PK_check                  PERFORMANCE_check  \
# 0   PK>=0.0   PERFORMANCE<0.021657592256503287
# 1   PK>=0.0   PERFORMANCE<0.021657592256503287
# 2   PK>=0.0  PERFORMANCE>=0.021657592256503287
# 3   PK>=0.0  PERFORMANCE>=0.021657592256503287
# 4   PK>=0.0   PERFORMANCE<0.021657592256503287
# ..      ...                                ...
# 82  PK>=0.0   PERFORMANCE<0.021657592256503287
# 83  PK>=0.0   PERFORMANCE<0.021657592256503287
# 84  PK>=0.0   PERFORMANCE<0.021657592256503287
# 85  PK>=0.0   PERFORMANCE<0.021657592256503287
# 86  PK>=0.0   PERFORMANCE<0.021657592256503287
#
#                   COMPETENCY_check                  LEARNING_POINT_check  \
# 0   COMPETENCY>=0.4225828262339418  LEARNING_POINT<0.0034482758620689655
# 1    COMPETENCY<0.4225828262339418  LEARNING_POINT<0.0034482758620689655
# 2    COMPETENCY<0.4225828262339418  LEARNING_POINT<0.0034482758620689655
# 3   COMPETENCY>=0.4225828262339418  LEARNING_POINT<0.0034482758620689655
# 4   COMPETENCY>=0.4225828262339418  LEARNING_POINT<0.0034482758620689655
# ..                             ...                                   ...
# 82   COMPETENCY<0.4225828262339418  LEARNING_POINT<0.0034482758620689655
# 83   COMPETENCY<0.4225828262339418  LEARNING_POINT<0.0034482758620689655
# 84   COMPETENCY<0.4225828262339418  LEARNING_POINT<0.0034482758620689655
# 85   COMPETENCY<0.4225828262339418  LEARNING_POINT<0.0034482758620689655
# 86   COMPETENCY<0.4225828262339418  LEARNING_POINT<0.0034482758620689655
#
#                 Kerja_Ibadah_check               Apresiasi_check  \
# 0    Kerja_Ibadah<0.79272030651341   Apresiasi<0.654181529924693
# 1    Kerja_Ibadah<0.79272030651341   Apresiasi<0.654181529924693
# 2   Kerja_Ibadah>=0.79272030651341  Apresiasi>=0.654181529924693
# 3   Kerja_Ibadah>=0.79272030651341  Apresiasi>=0.654181529924693
# 4    Kerja_Ibadah<0.79272030651341   Apresiasi<0.654181529924693
# ..                             ...                           ...
# 82   Kerja_Ibadah<0.79272030651341   Apresiasi<0.654181529924693
# 83   Kerja_Ibadah<0.79272030651341   Apresiasi<0.654181529924693
# 84   Kerja_Ibadah<0.79272030651341   Apresiasi<0.654181529924693
# 85  Kerja_Ibadah>=0.79272030651341   Apresiasi<0.654181529924693
# 86   Kerja_Ibadah<0.79272030651341  Apresiasi>=0.654181529924693
#
#                   Lebih_cepat_check                Aktif_bersama_check
# 0    Lebih_cepat<0.5790725326991676   Aktif_bersama<0.7200328407224957
# 1    Lebih_cepat<0.5790725326991676   Aktif_bersama<0.7200328407224957
# 2   Lebih_cepat>=0.5790725326991676  Aktif_bersama>=0.7200328407224957
# 3   Lebih_cepat>=0.5790725326991676  Aktif_bersama>=0.7200328407224957
# 4    Lebih_cepat<0.5790725326991676   Aktif_bersama<0.7200328407224957
# ..                              ...                                ...
# 82   Lebih_cepat<0.5790725326991676   Aktif_bersama<0.7200328407224957
# 83   Lebih_cepat<0.5790725326991676   Aktif_bersama<0.7200328407224957
# 84   Lebih_cepat<0.5790725326991676   Aktif_bersama<0.7200328407224957
# 85   Lebih_cepat<0.5790725326991676  Aktif_bersama>=0.7200328407224957
# 86   Lebih_cepat<0.5790725326991676  Aktif_bersama>=0.7200328407224957
#
# [87 rows x 8 columns]

# %%
len(data2)
# Out:
# 528

# %%
records = []
for i in range(0, len(data1)):
    records.append([str(data1.values[i,j]) for j in range(0, 8)])

# %%
# !pip install apyori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5974 sha256=d5fa8c663766069c9f0ab5888f2a1626ad922fa51ff921b1e7b8dbcb013726b7
#   Stored in directory: /root/.cache/pip/wheels/cb/f6/e1/57973c631d27efd1a2f375bd6a83b2a616c4021f24aab84080
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from apyori import apriori

# %%
association_rules = apriori(records, min_support=0.55, min_confidence=0.9, min_length = 2)

# %%
association_results = list(association_rules)

# %%
print(len(association_results))
# Out:
# 1

# %%
for i in association_results:
  print(i)
# Out:
# RelationRecord(items=frozenset({'PERFORMANCE>=0.8809815950920243', 'PK>=0.9254869259634284'}), support=0.6134969325153374, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PERFORMANCE>=0.8809815950920243'}), items_add=frozenset({'PK>=0.9254869259634284'}), confidence=0.9803921568627451, lift=1.5075841657417683), OrderedStatistic(items_base=frozenset({'PK>=0.9254869259634284'}), items_add=frozenset({'PERFORMANCE>=0.8809815950920243'}), confidence=0.9433962264150944, lift=1.5075841657417683)])

# %% [markdown]
# Cluster 2

# %%
records = []
for i in range(0, len(data2)):
    records.append([str(data2.values[i,j]) for j in range(0, 8)])

# %%
association_rules = apriori(records, min_support=0.55, min_confidence=0.9, min_length = 2)

# %%
association_results = list(association_rules)

# %%
print(len(association_results))
# Out:
# 1

# %%
for i in association_results:
  print(i)
# Out:
# RelationRecord(items=frozenset({'PERFORMANCE>=0.8809815950920243', 'PK>=0.9254869259634284'}), support=0.6134969325153374, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PERFORMANCE>=0.8809815950920243'}), items_add=frozenset({'PK>=0.9254869259634284'}), confidence=0.9803921568627451, lift=1.5075841657417683), OrderedStatistic(items_base=frozenset({'PK>=0.9254869259634284'}), items_add=frozenset({'PERFORMANCE>=0.8809815950920243'}), confidence=0.9433962264150944, lift=1.5075841657417683)])

# %% [markdown]
# Cluster 3

# %%
records = []
for i in range(0, len(data3)):
    records.append([str(data3.values[i,j]) for j in range(0, 8)])

# %%
association_rules = apriori(records, min_support=0.55, min_confidence=0.9, min_length = 2)

# %%
association_results = list(association_rules)

# %%
print(len(association_results))
# Out:
# 1

# %%
for i in association_results:
  print(i)
# Out:
# RelationRecord(items=frozenset({'Aktif_bersama>=0.8728558627752174', 'Apresiasi>=0.8777654183660857'}), support=0.5878136200716846, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama>=0.8728558627752174'}), items_add=frozenset({'Apresiasi>=0.8777654183660857'}), confidence=0.901098901098901, lift=1.34802462952597)])

# %% [markdown]
# Cluster 4

# %%
cluster4
# Out:
#           NIK   PK  PERFORMANCE  COMPETENCY  LEARNING_POINT  Kerja_Ibadah  \
# 0   201791264  0.0     0.000000    0.441176             0.0      0.722222
# 1   201791265  0.0     0.000000    0.411765             0.0      0.744444
# 2   201791266  0.0     0.042105    0.411765             0.0      0.911111
# 3   201791262  0.0     0.031579    0.558824             0.0      0.911111
# 4   201791261  0.0     0.000000    0.441176             0.0      0.733333
# ..        ...  ...          ...         ...             ...           ...
# 82  199691301  0.0     0.000000    0.264706             0.0      0.722222
# 83  201191172  0.0     0.000000    0.264706             0.0      0.700000
# 84  200891138  0.0     0.000000    0.411765             0.0      0.655556
# 85  200391120  0.0     0.010526    0.411765             0.0      0.811111
# 86  201291193  0.0     0.010526    0.411765             0.0      0.688889
#
#     Apresiasi  Lebih_cepat  Aktif_bersama  Cluster PERFORMANCE_check  \
# 0    0.413793     0.517241       0.607143        4     PERFORMANCE=0
# 1    0.396552     0.517241       0.607143        4     PERFORMANCE=0
# 2    0.982759     0.965517       0.982143        4     PERFORMANCE>0
# 3    0.810345     0.827586       1.000000        4     PERFORMANCE>0
# 4    0.413793     0.517241       0.607143        4     PERFORMANCE=0
# ..        ...          ...            ...      ...               ...
# 82   0.603448     0.534483       0.607143        4     PERFORMANCE=0
# 83   0.603448     0.241379       0.571429        4     PERFORMANCE=0
# 84   0.603448     0.413793       0.678571        4     PERFORMANCE=0
# 85   0.603448     0.517241       0.803571        4     PERFORMANCE>0
# 86   0.689655     0.431034       0.803571        4     PERFORMANCE>0
#
#    LEARNING_POINT_check PK_check                COMPETENCY_check  \
# 0      LEARNING_POINT=0  PK>=0.0  COMPETENCY>=0.4225828262339418
# 1      LEARNING_POINT=0  PK>=0.0   COMPETENCY<0.4225828262339418
# 2      LEARNING_POINT=0  PK>=0.0   COMPETENCY<0.4225828262339418
# 3      LEARNING_POINT=0  PK>=0.0  COMPETENCY>=0.4225828262339418
# 4      LEARNING_POINT=0  PK>=0.0  COMPETENCY>=0.4225828262339418
# ..                  ...      ...                             ...
# 82     LEARNING_POINT=0  PK>=0.0   COMPETENCY<0.4225828262339418
# 83     LEARNING_POINT=0  PK>=0.0   COMPETENCY<0.4225828262339418
# 84     LEARNING_POINT=0  PK>=0.0   COMPETENCY<0.4225828262339418
# 85     LEARNING_POINT=0  PK>=0.0   COMPETENCY<0.4225828262339418
# 86     LEARNING_POINT=0  PK>=0.0   COMPETENCY<0.4225828262339418
#
#                 Kerja_Ibadah_check               Apresiasi_check  \
# 0    Kerja_Ibadah<0.79272030651341   Apresiasi<0.654181529924693
# 1    Kerja_Ibadah<0.79272030651341   Apresiasi<0.654181529924693
# 2   Kerja_Ibadah>=0.79272030651341  Apresiasi>=0.654181529924693
# 3   Kerja_Ibadah>=0.79272030651341  Apresiasi>=0.654181529924693
# 4    Kerja_Ibadah<0.79272030651341   Apresiasi<0.654181529924693
# ..                             ...                           ...
# 82   Kerja_Ibadah<0.79272030651341   Apresiasi<0.654181529924693
# 83   Kerja_Ibadah<0.79272030651341   Apresiasi<0.654181529924693
# 84   Kerja_Ibadah<0.79272030651341   Apresiasi<0.654181529924693
# 85  Kerja_Ibadah>=0.79272030651341   Apresiasi<0.654181529924693
# 86   Kerja_Ibadah<0.79272030651341  Apresiasi>=0.654181529924693
#
#                   Lebih_cepat_check                Aktif_bersama_check
# 0    Lebih_cepat<0.5790725326991676   Aktif_bersama<0.7200328407224957
# 1    Lebih_cepat<0.5790725326991676   Aktif_bersama<0.7200328407224957
# 2   Lebih_cepat>=0.5790725326991676  Aktif_bersama>=0.7200328407224957
# 3   Lebih_cepat>=0.5790725326991676  Aktif_bersama>=0.7200328407224957
# 4    Lebih_cepat<0.5790725326991676   Aktif_bersama<0.7200328407224957
# ..                              ...                                ...
# 82   Lebih_cepat<0.5790725326991676   Aktif_bersama<0.7200328407224957
# 83   Lebih_cepat<0.5790725326991676   Aktif_bersama<0.7200328407224957
# 84   Lebih_cepat<0.5790725326991676   Aktif_bersama<0.7200328407224957
# 85   Lebih_cepat<0.5790725326991676  Aktif_bersama>=0.7200328407224957
# 86   Lebih_cepat<0.5790725326991676  Aktif_bersama>=0.7200328407224957
#
# [87 rows x 18 columns]

# %%
count = 0
for i in cluster4['Aktif_bersama']:
  if i>=0.607143	:
    count+=1
print(count)
# Out:
# 40

# %%
records = []
for i in range(0, len(data4)):
    records.append([str(data4.values[i,j]) for j in range(0, 8)])

# %%
association_rules = apriori(records, min_support=0.75, min_confidence=0.95, min_length = 2)

# %%
association_results = list(association_rules)

# %%
print(len(association_results))
# Out:
# 3

# %%
for i in association_results:
  print(i)
# Out:
# RelationRecord(items=frozenset({'LEARNING_POINT=0'}), support=0.9885057471264368, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'LEARNING_POINT=0'}), confidence=0.9885057471264368, lift=1.0)])
# RelationRecord(items=frozenset({'PK>=0.0'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'PK>=0.0', 'LEARNING_POINT=0'}), support=0.9885057471264368, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'PK>=0.0', 'LEARNING_POINT=0'}), confidence=0.9885057471264368, lift=1.0), OrderedStatistic(items_base=frozenset({'LEARNING_POINT=0'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'PK>=0.0'}), items_add=frozenset({'LEARNING_POINT=0'}), confidence=0.9885057471264368, lift=1.0)])

# %% [markdown]
# # **CLUSTER 2**

# %%
data2
# Out:
#                    PK_check                PERFORMANCE_check  \
# 0    PK>=0.9024959373307221  PERFORMANCE>=0.8723288908967697
# 1    PK>=0.9024959373307221  PERFORMANCE>=0.8723288908967697
# 2    PK>=0.9024959373307221  PERFORMANCE>=0.8723288908967697
# 3    PK>=0.9024959373307221  PERFORMANCE>=0.8723288908967697
# 4     PK<0.9024959373307221   PERFORMANCE<0.8723288908967697
# ..                      ...                              ...
# 228   PK<0.9024959373307221   PERFORMANCE<0.8723288908967697
# 229  PK>=0.9024959373307221   PERFORMANCE<0.8723288908967697
# 230  PK>=0.9024959373307221   PERFORMANCE<0.8723288908967697
# 231  PK>=0.9024959373307221  PERFORMANCE>=0.8723288908967697
# 232  PK>=0.9024959373307221  PERFORMANCE>=0.8723288908967697
#
#                    COMPETENCY_check                 LEARNING_POINT_check  \
# 0     COMPETENCY<0.5478414541782377  LEARNING_POINT>=0.45098712446351924
# 1    COMPETENCY>=0.5478414541782377  LEARNING_POINT>=0.45098712446351924
# 2     COMPETENCY<0.5478414541782377  LEARNING_POINT>=0.45098712446351924
# 3    COMPETENCY>=0.5478414541782377  LEARNING_POINT>=0.45098712446351924
# 4     COMPETENCY<0.5478414541782377  LEARNING_POINT>=0.45098712446351924
# ..                              ...                                  ...
# 228  COMPETENCY>=0.5478414541782377   LEARNING_POINT<0.45098712446351924
# 229   COMPETENCY<0.5478414541782377  LEARNING_POINT>=0.45098712446351924
# 230   COMPETENCY<0.5478414541782377  LEARNING_POINT>=0.45098712446351924
# 231   COMPETENCY<0.5478414541782377  LEARNING_POINT>=0.45098712446351924
# 232   COMPETENCY<0.5478414541782377  LEARNING_POINT>=0.45098712446351924
#
#                    Kerja_Ibadah_check                Apresiasi_check  \
# 0    Kerja_Ibadah>=0.8959465903671914  Apresiasi>=0.8554092052686104
# 1    Kerja_Ibadah>=0.8959465903671914  Apresiasi>=0.8554092052686104
# 2     Kerja_Ibadah<0.8959465903671914  Apresiasi>=0.8554092052686104
# 3    Kerja_Ibadah>=0.8959465903671914  Apresiasi>=0.8554092052686104
# 4    Kerja_Ibadah>=0.8959465903671914  Apresiasi>=0.8554092052686104
# ..                                ...                            ...
# 228   Kerja_Ibadah<0.8959465903671914   Apresiasi<0.8554092052686104
# 229   Kerja_Ibadah<0.8959465903671914   Apresiasi<0.8554092052686104
# 230   Kerja_Ibadah<0.8959465903671914  Apresiasi>=0.8554092052686104
# 231  Kerja_Ibadah>=0.8959465903671914  Apresiasi>=0.8554092052686104
# 232   Kerja_Ibadah<0.8959465903671914   Apresiasi<0.8554092052686104
#
#                    Lebih_cepat_check               Aktif_bersama_check
# 0    Lebih_cepat>=0.8231463667307978  Aktif_bersama>=0.847946045370938
# 1    Lebih_cepat>=0.8231463667307978  Aktif_bersama>=0.847946045370938
# 2    Lebih_cepat>=0.8231463667307978  Aktif_bersama>=0.847946045370938
# 3    Lebih_cepat>=0.8231463667307978  Aktif_bersama>=0.847946045370938
# 4     Lebih_cepat<0.8231463667307978  Aktif_bersama>=0.847946045370938
# ..                               ...                               ...
# 228   Lebih_cepat<0.8231463667307978   Aktif_bersama<0.847946045370938
# 229   Lebih_cepat<0.8231463667307978   Aktif_bersama<0.847946045370938
# 230  Lebih_cepat>=0.8231463667307978  Aktif_bersama>=0.847946045370938
# 231  Lebih_cepat>=0.8231463667307978  Aktif_bersama>=0.847946045370938
# 232   Lebih_cepat<0.8231463667307978   Aktif_bersama<0.847946045370938
#
# [233 rows x 8 columns]

# %%
records = []
for i in range(0, 233):
    records.append([str(data2.values[i,j]) for j in range(0, 8)])

# %%
association_rules = apriori(records, min_support=0.4, min_confidence=0.9)

# %%
association_results = list(association_rules)
print(association_results)
# Out:
# [RelationRecord(items=frozenset({'PK>=0.9024959373307221', 'PERFORMANCE>=0.8723288908967697'}), support=0.5622317596566524, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PERFORMANCE>=0.8723288908967697'}), items_add=frozenset({'PK>=0.9024959373307221'}), confidence=0.9424460431654678, lift=1.5144132969486481), OrderedStatistic(items_base=frozenset({'PK>=0.9024959373307221'}), items_add=frozenset({'PERFORMANCE>=0.8723288908967697'}), confidence=0.903448275862069, lift=1.5144132969486481)]), RelationRecord(items=frozenset({'Aktif_bersama>=0.847946045370938', 'Apresiasi>=0.8554092052686104', 'Kerja_Ibadah>=0.8959465903671914'}), support=0.40772532188841204, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama>=0.847946045370938', 'Kerja_Ibadah>=0.8959465903671914'}), items_add=frozenset({'Apresiasi>=0.8554092052686104'}), confidence=0.9500000000000001, lift=1.603985507246377)]), RelationRecord(items=frozenset({'Lebih_cepat>=0.8231463667307978', 'Aktif_bersama>=0.847946045370938', 'Apresiasi>=0.8554092052686104'}), support=0.4592274678111588, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Lebih_cepat>=0.8231463667307978', 'Aktif_bersama>=0.847946045370938'}), items_add=frozenset({'Apresiasi>=0.8554092052686104'}), confidence=0.9224137931034483, lift=1.557408795602199), OrderedStatistic(items_base=frozenset({'Lebih_cepat>=0.8231463667307978', 'Apresiasi>=0.8554092052686104'}), items_add=frozenset({'Aktif_bersama>=0.847946045370938'}), confidence=0.9304347826086957, lift=1.5485093167701864)]), RelationRecord(items=frozenset({'Aktif_bersama>=0.847946045370938', 'PERFORMANCE>=0.8723288908967697', 'Apresiasi>=0.8554092052686104'}), support=0.40772532188841204, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PERFORMANCE>=0.8723288908967697', 'Apresiasi>=0.8554092052686104'}), items_add=frozenset({'Aktif_bersama>=0.847946045370938'}), confidence=0.9313725490196079, lift=1.5500700280112045)]), RelationRecord(items=frozenset({'PK>=0.9024959373307221', 'Aktif_bersama>=0.847946045370938', 'PERFORMANCE>=0.8723288908967697'}), support=0.4206008583690987, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama>=0.847946045370938', 'PERFORMANCE>=0.8723288908967697'}), items_add=frozenset({'PK>=0.9024959373307221'}), confidence=0.9245283018867925, lift=1.4856213402732596), OrderedStatistic(items_base=frozenset({'PK>=0.9024959373307221', 'Aktif_bersama>=0.847946045370938'}), items_add=frozenset({'PERFORMANCE>=0.8723288908967697'}), confidence=0.9702970297029704, lift=1.6264691217323173)]), RelationRecord(items=frozenset({'PK>=0.9024959373307221', 'PERFORMANCE>=0.8723288908967697', 'Apresiasi>=0.8554092052686104'}), support=0.4034334763948498, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PERFORMANCE>=0.8723288908967697', 'Apresiasi>=0.8554092052686104'}), items_add=frozenset({'PK>=0.9024959373307221'}), confidence=0.9215686274509803, lift=1.480865449628127), OrderedStatistic(items_base=frozenset({'PK>=0.9024959373307221', 'Apresiasi>=0.8554092052686104'}), items_add=frozenset({'PERFORMANCE>=0.8723288908967697'}), confidence=0.9791666666666666, lift=1.6413369304556356)]), RelationRecord(items=frozenset({'PK>=0.9024959373307221', 'Lebih_cepat>=0.8231463667307978', 'PERFORMANCE>=0.8723288908967697'}), support=0.4034334763948498, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Lebih_cepat>=0.8231463667307978', 'PERFORMANCE>=0.8723288908967697'}), items_add=frozenset({'PK>=0.9024959373307221'}), confidence=0.9215686274509803, lift=1.480865449628127), OrderedStatistic(items_base=frozenset({'PK>=0.9024959373307221', 'Lebih_cepat>=0.8231463667307978'}), items_add=frozenset({'PERFORMANCE>=0.8723288908967697'}), confidence=0.9690721649484536, lift=1.6244159311725879)])]

# %%
print(len(association_results))
# Out:
# 7

# %%
for i in association_results:
  print(i)
# Out:
# RelationRecord(items=frozenset({'PK>=0.9024959373307221', 'PERFORMANCE>=0.8723288908967697'}), support=0.5622317596566524, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PERFORMANCE>=0.8723288908967697'}), items_add=frozenset({'PK>=0.9024959373307221'}), confidence=0.9424460431654678, lift=1.5144132969486481), OrderedStatistic(items_base=frozenset({'PK>=0.9024959373307221'}), items_add=frozenset({'PERFORMANCE>=0.8723288908967697'}), confidence=0.903448275862069, lift=1.5144132969486481)])
# RelationRecord(items=frozenset({'Aktif_bersama>=0.847946045370938', 'Apresiasi>=0.8554092052686104', 'Kerja_Ibadah>=0.8959465903671914'}), support=0.40772532188841204, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama>=0.847946045370938', 'Kerja_Ibadah>=0.8959465903671914'}), items_add=frozenset({'Apresiasi>=0.8554092052686104'}), confidence=0.9500000000000001, lift=1.603985507246377)])
# RelationRecord(items=frozenset({'Lebih_cepat>=0.8231463667307978', 'Aktif_bersama>=0.847946045370938', 'Apresiasi>=0.8554092052686104'}), support=0.4592274678111588, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Lebih_cepat>=0.8231463667307978', 'Aktif_bersama>=0.847946045370938'}), items_add=frozenset({'Apresiasi>=0.8554092052686104'}), confidence=0.9224137931034483, lift=1.557408795602199), OrderedStatistic(items_base=frozenset({'Lebih_cepat>=0.8231463667307978', 'Apresiasi>=0.8554092052686104'}), items_add=frozenset({'Aktif_bersama>=0.847946045370938'}), confidence=0.9304347826086957, lift=1.5485093167701864)])
# RelationRecord(items=frozenset({'Aktif_bersama>=0.847946045370938', 'PERFORMANCE>=0.8723288908967697', 'Apresiasi>=0.8554092052686104'}), support=0.40772532188841204, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PERFORMANCE>=0.8723288908967697', 'Apresiasi>=0.8554092052686104'}), items_add=frozenset({'Aktif_bersama>=0.847946045370938'}), confidence=0.9313725490196079, lift=1.5500700280112045)])
# RelationRecord(items=frozenset({'PK>=0.9024959373307221', 'Aktif_bersama>=0.847946045370938', 'PERFORMANCE>=0.8723288908967697'}), support=0.4206008583690987, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama>=0.847946045370938', 'PERFORMANCE>=0.8723288908967697'}), items_add=frozenset({'PK>=0.9024959373307221'}), confidence=0.9245283018867925, lift=1.4856213402732596), OrderedStatistic(items_base=frozenset({'PK>=0.9024959373307221', 'Aktif_bersama>=0.847946045370938'}), items_add=frozenset({'PERFORMANCE>=0.8723288908967697'}), confidence=0.9702970297029704, lift=1.6264691217323173)])
# RelationRecord(items=frozenset({'PK>=0.9024959373307221', 'PERFORMANCE>=0.8723288908967697', 'Apresiasi>=0.8554092052686104'}), support=0.4034334763948498, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PERFORMANCE>=0.8723288908967697', 'Apresiasi>=0.8554092052686104'}), items_add=frozenset({'PK>=0.9024959373307221'}), confidence=0.9215686274509803, lift=1.480865449628127), OrderedStatistic(items_base=frozenset({'PK>=0.9024959373307221', 'Apresiasi>=0.8554092052686104'}), items_add=frozenset({'PERFORMANCE>=0.8723288908967697'}), confidence=0.9791666666666666, lift=1.6413369304556356)])
# RelationRecord(items=frozenset({'PK>=0.9024959373307221', 'Lebih_cepat>=0.8231463667307978', 'PERFORMANCE>=0.8723288908967697'}), support=0.4034334763948498, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Lebih_cepat>=0.8231463667307978', 'PERFORMANCE>=0.8723288908967697'}), items_add=frozenset({'PK>=0.9024959373307221'}), confidence=0.9215686274509803, lift=1.480865449628127), OrderedStatistic(items_base=frozenset({'PK>=0.9024959373307221', 'Lebih_cepat>=0.8231463667307978'}), items_add=frozenset({'PERFORMANCE>=0.8723288908967697'}), confidence=0.9690721649484536, lift=1.6244159311725879)])

# %% [markdown]
# ## CLUSTER **1**

# %%
data1
# Out:
#    PK_check                  PERFORMANCE_check  \
# 0   PK>=0.0   PERFORMANCE<0.021657592256503287
# 1   PK>=0.0   PERFORMANCE<0.021657592256503287
# 2   PK>=0.0  PERFORMANCE>=0.021657592256503287
# 3   PK>=0.0  PERFORMANCE>=0.021657592256503287
# 4   PK>=0.0   PERFORMANCE<0.021657592256503287
# ..      ...                                ...
# 82  PK>=0.0   PERFORMANCE<0.021657592256503287
# 83  PK>=0.0   PERFORMANCE<0.021657592256503287
# 84  PK>=0.0   PERFORMANCE<0.021657592256503287
# 85  PK>=0.0   PERFORMANCE<0.021657592256503287
# 86  PK>=0.0   PERFORMANCE<0.021657592256503287
#
#                   COMPETENCY_check                  LEARNING_POINT_check  \
# 0   COMPETENCY>=0.4225828262339418  LEARNING_POINT<0.0034482758620689655
# 1    COMPETENCY<0.4225828262339418  LEARNING_POINT<0.0034482758620689655
# 2    COMPETENCY<0.4225828262339418  LEARNING_POINT<0.0034482758620689655
# 3   COMPETENCY>=0.4225828262339418  LEARNING_POINT<0.0034482758620689655
# 4   COMPETENCY>=0.4225828262339418  LEARNING_POINT<0.0034482758620689655
# ..                             ...                                   ...
# 82   COMPETENCY<0.4225828262339418  LEARNING_POINT<0.0034482758620689655
# 83   COMPETENCY<0.4225828262339418  LEARNING_POINT<0.0034482758620689655
# 84   COMPETENCY<0.4225828262339418  LEARNING_POINT<0.0034482758620689655
# 85   COMPETENCY<0.4225828262339418  LEARNING_POINT<0.0034482758620689655
# 86   COMPETENCY<0.4225828262339418  LEARNING_POINT<0.0034482758620689655
#
#                 Kerja_Ibadah_check               Apresiasi_check  \
# 0    Kerja_Ibadah<0.79272030651341   Apresiasi<0.654181529924693
# 1    Kerja_Ibadah<0.79272030651341   Apresiasi<0.654181529924693
# 2   Kerja_Ibadah>=0.79272030651341  Apresiasi>=0.654181529924693
# 3   Kerja_Ibadah>=0.79272030651341  Apresiasi>=0.654181529924693
# 4    Kerja_Ibadah<0.79272030651341   Apresiasi<0.654181529924693
# ..                             ...                           ...
# 82   Kerja_Ibadah<0.79272030651341   Apresiasi<0.654181529924693
# 83   Kerja_Ibadah<0.79272030651341   Apresiasi<0.654181529924693
# 84   Kerja_Ibadah<0.79272030651341   Apresiasi<0.654181529924693
# 85  Kerja_Ibadah>=0.79272030651341   Apresiasi<0.654181529924693
# 86   Kerja_Ibadah<0.79272030651341  Apresiasi>=0.654181529924693
#
#                   Lebih_cepat_check                Aktif_bersama_check
# 0    Lebih_cepat<0.5790725326991676   Aktif_bersama<0.7200328407224957
# 1    Lebih_cepat<0.5790725326991676   Aktif_bersama<0.7200328407224957
# 2   Lebih_cepat>=0.5790725326991676  Aktif_bersama>=0.7200328407224957
# 3   Lebih_cepat>=0.5790725326991676  Aktif_bersama>=0.7200328407224957
# 4    Lebih_cepat<0.5790725326991676   Aktif_bersama<0.7200328407224957
# ..                              ...                                ...
# 82   Lebih_cepat<0.5790725326991676   Aktif_bersama<0.7200328407224957
# 83   Lebih_cepat<0.5790725326991676   Aktif_bersama<0.7200328407224957
# 84   Lebih_cepat<0.5790725326991676   Aktif_bersama<0.7200328407224957
# 85   Lebih_cepat<0.5790725326991676  Aktif_bersama>=0.7200328407224957
# 86   Lebih_cepat<0.5790725326991676  Aktif_bersama>=0.7200328407224957
#
# [87 rows x 8 columns]

# %%
records = []
for i in range(0, 87):
    records.append([str(data4.values[i,j]) for j in range(0, 8)])

# %%
association_rules = apriori(records, min_support=0.55, min_confidence=0.9, min_length=2)
# Out:
#   File "<ipython-input-59-ad48faa6a3bd>", line 1
#     association_rules = apriori(records, min_support=0.55 min_confidence=0.9, min_length=2)
#                                                                        ^
# SyntaxError: invalid syntax

# %%
association_results = list(association_rules)
print(association_results)
# Out:
# [RelationRecord(items=frozenset({'LEARNING_POINT<0.0034482758620689655'}), support=0.9885057471264368, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=0.9885057471264368, lift=1.0)]), RelationRecord(items=frozenset({'PK>=0.0'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'Aktif_bersama<0.7200328407224957'}), support=0.4482758620689655, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693'}), items_add=frozenset({'Aktif_bersama<0.7200328407224957'}), confidence=0.9069767441860466, lift=1.5174418604651163)]), RelationRecord(items=frozenset({'Kerja_Ibadah<0.79272030651341', 'Aktif_bersama<0.7200328407224957'}), support=0.5517241379310345, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341'}), confidence=0.923076923076923, lift=1.434065934065934)]), RelationRecord(items=frozenset({'LEARNING_POINT<0.0034482758620689655', 'Aktif_bersama<0.7200328407224957'}), support=0.5977011494252874, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442)]), RelationRecord(items=frozenset({'Lebih_cepat<0.5790725326991676', 'Aktif_bersama<0.7200328407224957'}), support=0.5862068965517241, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676'}), confidence=0.9807692307692306, lift=1.4221153846153842)]), RelationRecord(items=frozenset({'PERFORMANCE<0.021657592256503287', 'Aktif_bersama<0.7200328407224957'}), support=0.5977011494252874, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287'}), confidence=1.0, lift=1.2428571428571429)]), RelationRecord(items=frozenset({'Aktif_bersama<0.7200328407224957', 'PK>=0.0'}), support=0.5977011494252874, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({'Aktif_bersama>=0.7200328407224957', 'PK>=0.0'}), support=0.40229885057471265, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama>=0.7200328407224957'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'Kerja_Ibadah<0.79272030651341'}), support=0.4482758620689655, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341'}), confidence=0.9069767441860466, lift=1.4090531561461794)]), RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'LEARNING_POINT<0.0034482758620689655'}), support=0.4942528735632184, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442)]), RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'Lebih_cepat<0.5790725326991676'}), support=0.47126436781609193, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676'}), confidence=0.9534883720930232, lift=1.3825581395348836)]), RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'PERFORMANCE<0.021657592256503287'}), support=0.4942528735632184, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287'}), confidence=1.0, lift=1.2 ...

# %%
print(len(association_results))
# Out:
# 192

# %%
for i in association_results:
  print(i)
# Out:
# RelationRecord(items=frozenset({'LEARNING_POINT<0.0034482758620689655'}), support=0.9885057471264368, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=0.9885057471264368, lift=1.0)])
# RelationRecord(items=frozenset({'PK>=0.0'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'Aktif_bersama<0.7200328407224957'}), support=0.4482758620689655, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693'}), items_add=frozenset({'Aktif_bersama<0.7200328407224957'}), confidence=0.9069767441860466, lift=1.5174418604651163)])
# RelationRecord(items=frozenset({'Kerja_Ibadah<0.79272030651341', 'Aktif_bersama<0.7200328407224957'}), support=0.5517241379310345, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341'}), confidence=0.923076923076923, lift=1.434065934065934)])
# RelationRecord(items=frozenset({'LEARNING_POINT<0.0034482758620689655', 'Aktif_bersama<0.7200328407224957'}), support=0.5977011494252874, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442)])
# RelationRecord(items=frozenset({'Lebih_cepat<0.5790725326991676', 'Aktif_bersama<0.7200328407224957'}), support=0.5862068965517241, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676'}), confidence=0.9807692307692306, lift=1.4221153846153842)])
# RelationRecord(items=frozenset({'PERFORMANCE<0.021657592256503287', 'Aktif_bersama<0.7200328407224957'}), support=0.5977011494252874, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287'}), confidence=1.0, lift=1.2428571428571429)])
# RelationRecord(items=frozenset({'Aktif_bersama<0.7200328407224957', 'PK>=0.0'}), support=0.5977011494252874, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'Aktif_bersama>=0.7200328407224957', 'PK>=0.0'}), support=0.40229885057471265, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama>=0.7200328407224957'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'Kerja_Ibadah<0.79272030651341'}), support=0.4482758620689655, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341'}), confidence=0.9069767441860466, lift=1.4090531561461794)])
# RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'LEARNING_POINT<0.0034482758620689655'}), support=0.4942528735632184, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442)])
# RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'Lebih_cepat<0.5790725326991676'}), support=0.47126436781609193, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676'}), confidence=0.9534883720930232, lift=1.3825581395348836)])
# RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'PERFORMANCE<0.021657592256503287'}), support=0.4942528735632184, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287'}), confidence=1.0, lift=1.2428571428571429)])
# RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'PK>=0.0'}), support=0.4942528735632184, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'Apresiasi>=0.654181529924693', 'LEARNING_POINT<0.0034482758620689655'}), support=0.4942528735632184, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi>=0.654181529924693'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=0.9772727272727272, lift=0.9886363636363635)])
# RelationRecord(items=frozenset({'Apresiasi>=0.654181529924693', 'PK>=0.0'}), support=0.5057471264367817, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi>=0.654181529924693'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'COMPETENCY<0.4225828262339418', 'LEARNING_POINT<0.0034482758620689655'}), support=0.7471264367816092, ordered_statistics=[OrderedStatistic(items_base=frozenset({'COMPETENCY<0.4225828262339418'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442)])
# RelationRecord(items=frozenset({'COMPETENCY<0.4225828262339418', 'PK>=0.0'}), support=0.7471264367816092, ordered_statistics=[OrderedStatistic(items_base=frozenset({'COMPETENCY<0.4225828262339418'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'Kerja_Ibadah<0.79272030651341', 'LEARNING_POINT<0.0034482758620689655'}), support=0.6436781609195402, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442)])
# RelationRecord(items=frozenset({'Kerja_Ibadah<0.79272030651341', 'Lebih_cepat<0.5790725326991676'}), support=0.6091954022988506, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676'}), confidence=0.9464285714285715, lift=1.3723214285714287)])
# RelationRecord(items=frozenset({'Kerja_Ibadah<0.79272030651341', 'PERFORMANCE<0.021657592256503287'}), support=0.632183908045977, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287'}), confidence=0.9821428571428572, lift=1.2206632653061225)])
# RelationRecord(items=frozenset({'Kerja_Ibadah<0.79272030651341', 'PK>=0.0'}), support=0.6436781609195402, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'Lebih_cepat<0.5790725326991676', 'LEARNING_POINT<0.0034482758620689655'}), support=0.6896551724137931, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Lebih_cepat<0.5790725326991676'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442)])
# RelationRecord(items=frozenset({'PERFORMANCE<0.021657592256503287', 'LEARNING_POINT<0.0034482758620689655'}), support=0.8045977011494253, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PERFORMANCE<0.021657592256503287'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442)])
# RelationRecord(items=frozenset({'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), support=0.9885057471264368, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), confidence=0.9885057471264368, lift=1.0), OrderedStatistic(items_base=frozenset({'LEARNING_POINT<0.0034482758620689655'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'PK>=0.0'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=0.9885057471264368, lift=1.0)])
# RelationRecord(items=frozenset({'Lebih_cepat<0.5790725326991676', 'PERFORMANCE<0.021657592256503287'}), support=0.6781609195402298, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Lebih_cepat<0.5790725326991676'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287'}), confidence=0.9833333333333332, lift=1.222142857142857)])
# RelationRecord(items=frozenset({'Lebih_cepat<0.5790725326991676', 'PK>=0.0'}), support=0.6896551724137931, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Lebih_cepat<0.5790725326991676'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'PERFORMANCE<0.021657592256503287', 'PK>=0.0'}), support=0.8045977011494253, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PERFORMANCE<0.021657592256503287'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'Kerja_Ibadah<0.79272030651341', 'Aktif_bersama<0.7200328407224957'}), support=0.42528735632183906, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341'}), confidence=0.9487179487179487, lift=1.4739010989010988), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Kerja_Ibadah<0.79272030651341'}), items_add=frozenset({'Aktif_bersama<0.7200328407224957'}), confidence=0.9487179487179487, lift=1.5872781065088755)])
# RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'LEARNING_POINT<0.0034482758620689655', 'Aktif_bersama<0.7200328407224957'}), support=0.4482758620689655, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693'}), items_add=frozenset({'Aktif_bersama<0.7200328407224957', 'LEARNING_POINT<0.0034482758620689655'}), confidence=0.9069767441860466, lift=1.5174418604651163), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'LEARNING_POINT<0.0034482758620689655'}), items_add=frozenset({'Aktif_bersama<0.7200328407224957'}), confidence=0.9069767441860466, lift=1.5174418604651163)])
# RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'Lebih_cepat<0.5790725326991676', 'Aktif_bersama<0.7200328407224957'}), support=0.4482758620689655, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676', 'Aktif_bersama<0.7200328407224957'}), confidence=0.9069767441860466, lift=1.5471956224350207), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676'}), confidence=1.0, lift=1.45), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Lebih_cepat<0.5790725326991676'}), items_add=frozenset({'Aktif_bersama<0.7200328407224957'}), confidence=0.951219512195122, lift=1.5914634146341464)])
# RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'PERFORMANCE<0.021657592256503287', 'Aktif_bersama<0.7200328407224957'}), support=0.4482758620689655, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287', 'Aktif_bersama<0.7200328407224957'}), confidence=0.9069767441860466, lift=1.5174418604651163), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287'}), confidence=1.0, lift=1.2428571428571429), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'PERFORMANCE<0.021657592256503287'}), items_add=frozenset({'Aktif_bersama<0.7200328407224957'}), confidence=0.9069767441860466, lift=1.5174418604651163)])
# RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'Aktif_bersama<0.7200328407224957', 'PK>=0.0'}), support=0.4482758620689655, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693'}), items_add=frozenset({'Aktif_bersama<0.7200328407224957', 'PK>=0.0'}), confidence=0.9069767441860466, lift=1.5174418604651163), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'PK>=0.0'}), items_add=frozenset({'Aktif_bersama<0.7200328407224957'}), confidence=0.9069767441860466, lift=1.5174418604651163)])
# RelationRecord(items=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418', 'Aktif_bersama<0.7200328407224957'}), support=0.47126436781609193, ordered_statistics=[OrderedStatistic(items_base=frozenset({'COMPETENCY<0.4225828262339418', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341'}), confidence=0.9318181818181817, lift=1.4476461038961037), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418'}), items_add=frozenset({'Aktif_bersama<0.7200328407224957'}), confidence=0.911111111111111, lift=1.524358974358974)])
# RelationRecord(items=frozenset({'LEARNING_POINT<0.0034482758620689655', 'COMPETENCY<0.4225828262339418', 'Aktif_bersama<0.7200328407224957'}), support=0.5057471264367817, ordered_statistics=[OrderedStatistic(items_base=frozenset({'COMPETENCY<0.4225828262339418', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442)])
# RelationRecord(items=frozenset({'COMPETENCY<0.4225828262339418', 'Lebih_cepat<0.5790725326991676', 'Aktif_bersama<0.7200328407224957'}), support=0.4942528735632184, ordered_statistics=[OrderedStatistic(items_base=frozenset({'COMPETENCY<0.4225828262339418', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676'}), confidence=0.9772727272727272, lift=1.4170454545454543)])
# RelationRecord(items=frozenset({'COMPETENCY<0.4225828262339418', 'PERFORMANCE<0.021657592256503287', 'Aktif_bersama<0.7200328407224957'}), support=0.5057471264367817, ordered_statistics=[OrderedStatistic(items_base=frozenset({'COMPETENCY<0.4225828262339418', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287'}), confidence=1.0, lift=1.2428571428571429)])
# RelationRecord(items=frozenset({'COMPETENCY<0.4225828262339418', 'Aktif_bersama<0.7200328407224957', 'PK>=0.0'}), support=0.5057471264367817, ordered_statistics=[OrderedStatistic(items_base=frozenset({'COMPETENCY<0.4225828262339418', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'Kerja_Ibadah<0.79272030651341', 'LEARNING_POINT<0.0034482758620689655', 'Aktif_bersama<0.7200328407224957'}), support=0.5517241379310345, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341', 'LEARNING_POINT<0.0034482758620689655'}), confidence=0.923076923076923, lift=1.434065934065934), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442), OrderedStatistic(items_base=frozenset({'LEARNING_POINT<0.0034482758620689655', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341'}), confidence=0.923076923076923, lift=1.434065934065934)])
# RelationRecord(items=frozenset({'Kerja_Ibadah<0.79272030651341', 'Lebih_cepat<0.5790725326991676', 'Aktif_bersama<0.7200328407224957'}), support=0.5517241379310345, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341', 'Lebih_cepat<0.5790725326991676'}), confidence=0.923076923076923, lift=1.5152394775036282), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676'}), confidence=1.0, lift=1.45), OrderedStatistic(items_base=frozenset({'Lebih_cepat<0.5790725326991676', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341'}), confidence=0.9411764705882354, lift=1.46218487394958), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'Lebih_cepat<0.5790725326991676'}), items_add=frozenset({'Aktif_bersama<0.7200328407224957'}), confidence=0.9056603773584905, lift=1.5152394775036282)])
# RelationRecord(items=frozenset({'Kerja_Ibadah<0.79272030651341', 'PERFORMANCE<0.021657592256503287', 'Aktif_bersama<0.7200328407224957'}), support=0.5517241379310345, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341', 'PERFORMANCE<0.021657592256503287'}), confidence=0.923076923076923, lift=1.46013986013986), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287'}), confidence=1.0, lift=1.2428571428571429), OrderedStatistic(items_base=frozenset({'PERFORMANCE<0.021657592256503287', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341'}), confidence=0.923076923076923, lift=1.434065934065934)])
# RelationRecord(items=frozenset({'Kerja_Ibadah<0.79272030651341', 'Aktif_bersama<0.7200328407224957', 'PK>=0.0'}), support=0.5517241379310345, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341', 'PK>=0.0'}), confidence=0.923076923076923, lift=1.434065934065934), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'Aktif_bersama<0.7200328407224957', 'PK>=0.0'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341'}), confidence=0.923076923076923, lift=1.434065934065934)])
# RelationRecord(items=frozenset({'LEARNING_POINT<0.0034482758620689655', 'Lebih_cepat<0.5790725326991676', 'Aktif_bersama<0.7200328407224957'}), support=0.5862068965517241, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676', 'LEARNING_POINT<0.0034482758620689655'}), confidence=0.9807692307692306, lift=1.4221153846153842), OrderedStatistic(items_base=frozenset({'LEARNING_POINT<0.0034482758620689655', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676'}), confidence=0.9807692307692306, lift=1.4221153846153842), OrderedStatistic(items_base=frozenset({'Lebih_cepat<0.5790725326991676', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442)])
# RelationRecord(items=frozenset({'LEARNING_POINT<0.0034482758620689655', 'PERFORMANCE<0.021657592256503287', 'Aktif_bersama<0.7200328407224957'}), support=0.5977011494252874, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287', 'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.2428571428571429), OrderedStatistic(items_base=frozenset({'LEARNING_POINT<0.0034482758620689655', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287'}), confidence=1.0, lift=1.2428571428571429), OrderedStatistic(items_base=frozenset({'PERFORMANCE<0.021657592256503287', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442)])
# RelationRecord(items=frozenset({'LEARNING_POINT<0.0034482758620689655', 'Aktif_bersama<0.7200328407224957', 'PK>=0.0'}), support=0.5977011494252874, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), confidence=1.0, lift=1.0116279069767442), OrderedStatistic(items_base=frozenset({'LEARNING_POINT<0.0034482758620689655', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'Aktif_bersama<0.7200328407224957', 'PK>=0.0'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442)])
# RelationRecord(items=frozenset({'Lebih_cepat<0.5790725326991676', 'PERFORMANCE<0.021657592256503287', 'Aktif_bersama<0.7200328407224957'}), support=0.5862068965517241, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676', 'PERFORMANCE<0.021657592256503287'}), confidence=0.9807692307692306, lift=1.4462190352020858), OrderedStatistic(items_base=frozenset({'Lebih_cepat<0.5790725326991676', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287'}), confidence=1.0, lift=1.2428571428571429), OrderedStatistic(items_base=frozenset({'PERFORMANCE<0.021657592256503287', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676'}), confidence=0.9807692307692306, lift=1.4221153846153842)])
# RelationRecord(items=frozenset({'Lebih_cepat<0.5790725326991676', 'Aktif_bersama<0.7200328407224957', 'PK>=0.0'}), support=0.5862068965517241, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676', 'PK>=0.0'}), confidence=0.9807692307692306, lift=1.4221153846153842), OrderedStatistic(items_base=frozenset({'Lebih_cepat<0.5790725326991676', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'Aktif_bersama<0.7200328407224957', 'PK>=0.0'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676'}), confidence=0.9807692307692306, lift=1.4221153846153842)])
# RelationRecord(items=frozenset({'PERFORMANCE<0.021657592256503287', 'Aktif_bersama<0.7200328407224957', 'PK>=0.0'}), support=0.5977011494252874, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287', 'PK>=0.0'}), confidence=1.0, lift=1.2428571428571429), OrderedStatistic(items_base=frozenset({'PERFORMANCE<0.021657592256503287', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'Aktif_bersama<0.7200328407224957', 'PK>=0.0'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287'}), confidence=1.0, lift=1.2428571428571429)])
# RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'COMPETENCY<0.4225828262339418', 'LEARNING_POINT<0.0034482758620689655'}), support=0.40229885057471265, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'COMPETENCY<0.4225828262339418'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442)])
# RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'COMPETENCY<0.4225828262339418', 'PERFORMANCE<0.021657592256503287'}), support=0.40229885057471265, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'COMPETENCY<0.4225828262339418'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287'}), confidence=1.0, lift=1.2428571428571429)])
# RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'COMPETENCY<0.4225828262339418', 'PK>=0.0'}), support=0.40229885057471265, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'COMPETENCY<0.4225828262339418'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'Kerja_Ibadah<0.79272030651341', 'LEARNING_POINT<0.0034482758620689655'}), support=0.4482758620689655, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341', 'LEARNING_POINT<0.0034482758620689655'}), confidence=0.9069767441860466, lift=1.4090531561461794), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Kerja_Ibadah<0.79272030651341'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'LEARNING_POINT<0.0034482758620689655'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341'}), confidence=0.9069767441860466, lift=1.4090531561461794)])
# RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'Kerja_Ibadah<0.79272030651341', 'Lebih_cepat<0.5790725326991676'}), support=0.4367816091954023, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Kerja_Ibadah<0.79272030651341'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676'}), confidence=0.9743589743589743, lift=1.4128205128205127), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Lebih_cepat<0.5790725326991676'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341'}), confidence=0.926829268292683, lift=1.4398954703832754)])
# RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'Kerja_Ibadah<0.79272030651341', 'PERFORMANCE<0.021657592256503287'}), support=0.4482758620689655, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341', 'PERFORMANCE<0.021657592256503287'}), confidence=0.9069767441860466, lift=1.4346723044397465), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Kerja_Ibadah<0.79272030651341'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287'}), confidence=1.0, lift=1.2428571428571429), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'PERFORMANCE<0.021657592256503287'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341'}), confidence=0.9069767441860466, lift=1.4090531561461794)])
# RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'Kerja_Ibadah<0.79272030651341', 'PK>=0.0'}), support=0.4482758620689655, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341', 'PK>=0.0'}), confidence=0.9069767441860466, lift=1.4090531561461794), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Kerja_Ibadah<0.79272030651341'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'PK>=0.0'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341'}), confidence=0.9069767441860466, lift=1.4090531561461794)])
# RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'Lebih_cepat<0.5790725326991676', 'LEARNING_POINT<0.0034482758620689655'}), support=0.47126436781609193, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676', 'LEARNING_POINT<0.0034482758620689655'}), confidence=0.9534883720930232, lift=1.3825581395348836), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'LEARNING_POINT<0.0034482758620689655'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676'}), confidence=0.9534883720930232, lift=1.3825581395348836), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Lebih_cepat<0.5790725326991676'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442)])
# RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'PERFORMANCE<0.021657592256503287', 'LEARNING_POINT<0.0034482758620689655'}), support=0.4942528735632184, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287', 'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.2428571428571429), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'LEARNING_POINT<0.0034482758620689655'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287'}), confidence=1.0, lift=1.2428571428571429), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'PERFORMANCE<0.021657592256503287'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442)])
# RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), support=0.4942528735632184, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), confidence=1.0, lift=1.0116279069767442), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'LEARNING_POINT<0.0034482758620689655'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'PK>=0.0'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442)])
# RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'Lebih_cepat<0.5790725326991676', 'PERFORMANCE<0.021657592256503287'}), support=0.47126436781609193, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676', 'PERFORMANCE<0.021657592256503287'}), confidence=0.9534883720930232, lift=1.4059913283405596), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Lebih_cepat<0.5790725326991676'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287'}), confidence=1.0, lift=1.2428571428571429), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'PERFORMANCE<0.021657592256503287'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676'}), confidence=0.9534883720930232, lift=1.3825581395348836)])
# RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'Lebih_cepat<0.5790725326991676', 'PK>=0.0'}), support=0.47126436781609193, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676', 'PK>=0.0'}), confidence=0.9534883720930232, lift=1.3825581395348836), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Lebih_cepat<0.5790725326991676'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'PK>=0.0'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676'}), confidence=0.9534883720930232, lift=1.3825581395348836)])
# RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'PERFORMANCE<0.021657592256503287', 'PK>=0.0'}), support=0.4942528735632184, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287', 'PK>=0.0'}), confidence=1.0, lift=1.2428571428571429), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'PERFORMANCE<0.021657592256503287'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'PK>=0.0'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287'}), confidence=1.0, lift=1.2428571428571429)])
# RelationRecord(items=frozenset({'Apresiasi>=0.654181529924693', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), support=0.4942528735632184, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi>=0.654181529924693'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), confidence=0.9772727272727272, lift=0.9886363636363635), OrderedStatistic(items_base=frozenset({'Apresiasi>=0.654181529924693', 'LEARNING_POINT<0.0034482758620689655'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'Apresiasi>=0.654181529924693', 'PK>=0.0'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=0.9772727272727272, lift=0.9886363636363635)])
# RelationRecord(items=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418', 'LEARNING_POINT<0.0034482758620689655'}), support=0.5172413793103449, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442)])
# RelationRecord(items=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418', 'Lebih_cepat<0.5790725326991676'}), support=0.4942528735632184, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676'}), confidence=0.9555555555555555, lift=1.3855555555555554)])
# RelationRecord(items=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418', 'PERFORMANCE<0.021657592256503287'}), support=0.5172413793103449, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287'}), confidence=1.0, lift=1.2428571428571429)])
# RelationRecord(items=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418', 'PK>=0.0'}), support=0.5172413793103449, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'COMPETENCY<0.4225828262339418', 'Lebih_cepat<0.5790725326991676', 'LEARNING_POINT<0.0034482758620689655'}), support=0.5517241379310345, ordered_statistics=[OrderedStatistic(items_base=frozenset({'COMPETENCY<0.4225828262339418', 'Lebih_cepat<0.5790725326991676'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442)])
# RelationRecord(items=frozenset({'COMPETENCY<0.4225828262339418', 'PERFORMANCE<0.021657592256503287', 'LEARNING_POINT<0.0034482758620689655'}), support=0.6666666666666666, ordered_statistics=[OrderedStatistic(items_base=frozenset({'COMPETENCY<0.4225828262339418', 'PERFORMANCE<0.021657592256503287'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442)])
# RelationRecord(items=frozenset({'COMPETENCY<0.4225828262339418', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), support=0.7471264367816092, ordered_statistics=[OrderedStatistic(items_base=frozenset({'COMPETENCY<0.4225828262339418'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), confidence=1.0, lift=1.0116279069767442), OrderedStatistic(items_base=frozenset({'COMPETENCY<0.4225828262339418', 'LEARNING_POINT<0.0034482758620689655'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'COMPETENCY<0.4225828262339418', 'PK>=0.0'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442)])
# RelationRecord(items=frozenset({'COMPETENCY<0.4225828262339418', 'Lebih_cepat<0.5790725326991676', 'PERFORMANCE<0.021657592256503287'}), support=0.5517241379310345, ordered_statistics=[OrderedStatistic(items_base=frozenset({'COMPETENCY<0.4225828262339418', 'Lebih_cepat<0.5790725326991676'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287'}), confidence=1.0, lift=1.2428571428571429)])
# RelationRecord(items=frozenset({'COMPETENCY<0.4225828262339418', 'Lebih_cepat<0.5790725326991676', 'PK>=0.0'}), support=0.5517241379310345, ordered_statistics=[OrderedStatistic(items_base=frozenset({'COMPETENCY<0.4225828262339418', 'Lebih_cepat<0.5790725326991676'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'COMPETENCY<0.4225828262339418', 'PERFORMANCE<0.021657592256503287', 'PK>=0.0'}), support=0.6666666666666666, ordered_statistics=[OrderedStatistic(items_base=frozenset({'COMPETENCY<0.4225828262339418', 'PERFORMANCE<0.021657592256503287'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'Kerja_Ibadah<0.79272030651341', 'Lebih_cepat<0.5790725326991676', 'LEARNING_POINT<0.0034482758620689655'}), support=0.6091954022988506, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676', 'LEARNING_POINT<0.0034482758620689655'}), confidence=0.9464285714285715, lift=1.3723214285714287), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'LEARNING_POINT<0.0034482758620689655'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676'}), confidence=0.9464285714285715, lift=1.3723214285714287), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'Lebih_cepat<0.5790725326991676'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442)])
# RelationRecord(items=frozenset({'Kerja_Ibadah<0.79272030651341', 'PERFORMANCE<0.021657592256503287', 'LEARNING_POINT<0.0034482758620689655'}), support=0.632183908045977, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287', 'LEARNING_POINT<0.0034482758620689655'}), confidence=0.9821428571428572, lift=1.2206632653061225), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'LEARNING_POINT<0.0034482758620689655'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287'}), confidence=0.9821428571428572, lift=1.2206632653061225), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'PERFORMANCE<0.021657592256503287'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442)])
# RelationRecord(items=frozenset({'Kerja_Ibadah<0.79272030651341', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), support=0.6436781609195402, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), confidence=1.0, lift=1.0116279069767442), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'LEARNING_POINT<0.0034482758620689655'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'PK>=0.0'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442)])
# RelationRecord(items=frozenset({'Kerja_Ibadah<0.79272030651341', 'Lebih_cepat<0.5790725326991676', 'PERFORMANCE<0.021657592256503287'}), support=0.5977011494252874, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676', 'PERFORMANCE<0.021657592256503287'}), confidence=0.9285714285714286, lift=1.3692493946731237), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'Lebih_cepat<0.5790725326991676'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287'}), confidence=0.9811320754716981, lift=1.2194070080862534), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'PERFORMANCE<0.021657592256503287'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676'}), confidence=0.9454545454545455, lift=1.3709090909090909)])
# RelationRecord(items=frozenset({'Kerja_Ibadah<0.79272030651341', 'Lebih_cepat<0.5790725326991676', 'PK>=0.0'}), support=0.6091954022988506, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676', 'PK>=0.0'}), confidence=0.9464285714285715, lift=1.3723214285714287), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'Lebih_cepat<0.5790725326991676'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'PK>=0.0'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676'}), confidence=0.9464285714285715, lift=1.3723214285714287)])
# RelationRecord(items=frozenset({'Kerja_Ibadah<0.79272030651341', 'PERFORMANCE<0.021657592256503287', 'PK>=0.0'}), support=0.632183908045977, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287', 'PK>=0.0'}), confidence=0.9821428571428572, lift=1.2206632653061225), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'PERFORMANCE<0.021657592256503287'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'PK>=0.0'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287'}), confidence=0.9821428571428572, lift=1.2206632653061225)])
# RelationRecord(items=frozenset({'Lebih_cepat<0.5790725326991676', 'PERFORMANCE<0.021657592256503287', 'LEARNING_POINT<0.0034482758620689655'}), support=0.6781609195402298, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Lebih_cepat<0.5790725326991676'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287', 'LEARNING_POINT<0.0034482758620689655'}), confidence=0.9833333333333332, lift=1.222142857142857), OrderedStatistic(items_base=frozenset({'Lebih_cepat<0.5790725326991676', 'LEARNING_POINT<0.0034482758620689655'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287'}), confidence=0.9833333333333332, lift=1.222142857142857), OrderedStatistic(items_base=frozenset({'Lebih_cepat<0.5790725326991676', 'PERFORMANCE<0.021657592256503287'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442)])
# RelationRecord(items=frozenset({'Lebih_cepat<0.5790725326991676', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), support=0.6896551724137931, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Lebih_cepat<0.5790725326991676'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), confidence=1.0, lift=1.0116279069767442), OrderedStatistic(items_base=frozenset({'Lebih_cepat<0.5790725326991676', 'LEARNING_POINT<0.0034482758620689655'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'Lebih_cepat<0.5790725326991676', 'PK>=0.0'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442)])
# RelationRecord(items=frozenset({'PERFORMANCE<0.021657592256503287', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), support=0.8045977011494253, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PERFORMANCE<0.021657592256503287'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), confidence=1.0, lift=1.0116279069767442), OrderedStatistic(items_base=frozenset({'PERFORMANCE<0.021657592256503287', 'LEARNING_POINT<0.0034482758620689655'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'PERFORMANCE<0.021657592256503287', 'PK>=0.0'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442)])
# RelationRecord(items=frozenset({'Lebih_cepat<0.5790725326991676', 'PERFORMANCE<0.021657592256503287', 'PK>=0.0'}), support=0.6781609195402298, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Lebih_cepat<0.5790725326991676'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287', 'PK>=0.0'}), confidence=0.9833333333333332, lift=1.222142857142857), OrderedStatistic(items_base=frozenset({'Lebih_cepat<0.5790725326991676', 'PERFORMANCE<0.021657592256503287'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'Lebih_cepat<0.5790725326991676', 'PK>=0.0'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287'}), confidence=0.9833333333333332, lift=1.222142857142857)])
# RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'Kerja_Ibadah<0.79272030651341', 'Aktif_bersama<0.7200328407224957', 'LEARNING_POINT<0.0034482758620689655'}), support=0.42528735632183906, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341', 'LEARNING_POINT<0.0034482758620689655'}), confidence=0.9487179487179487, lift=1.4739010989010988), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Kerja_Ibadah<0.79272030651341'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655', 'Aktif_bersama<0.7200328407224957'}), confidence=0.9487179487179487, lift=1.5872781065088755), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Kerja_Ibadah<0.79272030651341', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.0116279069767442), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'LEARNING_POINT<0.0034482758620689655', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341'}), confidence=0.9487179487179487, lift=1.4739010989010988), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Kerja_Ibadah<0.79272030651341', 'LEARNING_POINT<0.0034482758620689655'}), items_add=frozenset({'Aktif_bersama<0.7200328407224957'}), confidence=0.9487179487179487, lift=1.5872781065088755)])
# RelationRecord(items=frozenset({'Apresiasi<0.654181529924693', 'Kerja_Ibadah<0.79272030651341', 'Lebih_cepat<0.5790725326991676', 'Aktif_bersama<0.7200328407224957'}), support=0.42528735632183906, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341', 'Lebih_cepat<0.5790725326991676'}), confidence=0.9487179487179487, lift=1.5573294629898402), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Kerja_Ibadah<0.79272030651341'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676', 'Aktif_bersama<0.7200328407224957'}), confidence=0.9487179487179487, lift=1.6184012066365008), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Lebih_cepat<0.5790725326991676'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341', 'Aktif_bersama<0.7200328407224957'}), confidence=0.9024390243902439, lift=1.6356707317073171), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Kerja_Ibadah<0.79272030651341', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676'}), confidence=1.0, lift=1.45), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Lebih_cepat<0.5790725326991676', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341'}), confidence=0.9487179487179487, lift=1.4739010989010988), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Kerja_Ibadah<0.79272030651341', 'Lebih_cepat<0.5790725326991676'}), items_add=frozenset({'Aktif_bersama<0.7200328407224957'}), confidence=0.9736842105263157, lift=1.6290485829959511)])
# ...
# RelationRecord(items=frozenset({'COMPETENCY<0.4225828262339418', 'Lebih_cepat<0.5790725326991676', 'Kerja_Ibadah<0.79272030651341', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0', 'PERFORMANCE<0.021657592256503287'}), support=0.4942528735632184, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676', 'PERFORMANCE<0.021657592256503287', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), confidence=0.9555555555555555, lift=1.4090395480225988), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418', 'LEARNING_POINT<0.0034482758620689655'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676', 'PERFORMANCE<0.021657592256503287', 'PK>=0.0'}), confidence=0.9555555555555555, lift=1.4090395480225988), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418', 'Lebih_cepat<0.5790725326991676'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), confidence=1.0, lift=1.2428571428571429), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418', 'PERFORMANCE<0.021657592256503287'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), confidence=0.9555555555555555, lift=1.3855555555555554), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418', 'PK>=0.0'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676', 'PERFORMANCE<0.021657592256503287', 'LEARNING_POINT<0.0034482758620689655'}), confidence=0.9555555555555555, lift=1.4090395480225988), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418', 'Lebih_cepat<0.5790725326991676', 'LEARNING_POINT<0.0034482758620689655'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287', 'PK>=0.0'}), confidence=1.0, lift=1.2428571428571429), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418', 'PERFORMANCE<0.021657592256503287', 'LEARNING_POINT<0.0034482758620689655'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676', 'PK>=0.0'}), confidence=0.9555555555555555, lift=1.3855555555555554), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676', 'PERFORMANCE<0.021657592256503287'}), confidence=0.9555555555555555, lift=1.4090395480225988), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418', 'Lebih_cepat<0.5790725326991676', 'PERFORMANCE<0.021657592256503287'}), items_add=frozenset({'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), confidence=1.0, lift=1.0116279069767442), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418', 'Lebih_cepat<0.5790725326991676', 'PK>=0.0'}), items_add=frozenset({'PERFORMANCE<0.021657592256503287', 'LEARNING_POINT<0.0034482758620689655'}), confidence=1.0, lift=1.2428571428571429), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418', 'PERFORMANCE<0.021657592256503287', 'PK>=0.0'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676', 'LEARNING_POINT<0.0034482758620689655'}), confidence=0.9555555555555555, lift=1.3855555555555554), OrderedStatistic(items_base=frozenset({'COMPETENCY<0.4225828262339418', 'Lebih_cepat<0.5790725326991676', 'Kerja_Ibadah<0.79272030651341', 'LEARNING_POINT<0.0034482758620689655', 'PERFORMANCE<0.021657592256503287'}), items_add=frozenset({'PK>=0.0'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'COMPETENCY<0.4225828262339418', 'Lebih_cepat<0.5790725326991676', 'Kerja_Ibadah<0.792 ...
# RelationRecord(items=frozenset({'Lebih_cepat<0.5790725326991676', 'Kerja_Ibadah<0.79272030651341', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0', 'Apresiasi<0.654181529924693', 'PERFORMANCE<0.021657592256503287', 'Aktif_bersama<0.7200328407224957'}), support=0.42528735632183906, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676', 'Kerja_Ibadah<0.79272030651341', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0', 'PERFORMANCE<0.021657592256503287'}), confidence=0.9487179487179487, lift=1.5872781065088755), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Kerja_Ibadah<0.79272030651341'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0', 'PERFORMANCE<0.021657592256503287', 'Aktif_bersama<0.7200328407224957'}), confidence=0.9487179487179487, lift=1.6184012066365008), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Lebih_cepat<0.5790725326991676'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0', 'PERFORMANCE<0.021657592256503287', 'Aktif_bersama<0.7200328407224957'}), confidence=0.9024390243902439, lift=1.6356707317073171), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Kerja_Ibadah<0.79272030651341', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676', 'PERFORMANCE<0.021657592256503287', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), confidence=1.0, lift=1.4745762711864407), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'LEARNING_POINT<0.0034482758620689655', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341', 'Lebih_cepat<0.5790725326991676', 'PERFORMANCE<0.021657592256503287', 'PK>=0.0'}), confidence=0.9487179487179487, lift=1.5872781065088755), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Lebih_cepat<0.5790725326991676', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341', 'PERFORMANCE<0.021657592256503287', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), confidence=0.9487179487179487, lift=1.5006993006993006), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'PERFORMANCE<0.021657592256503287', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341', 'Lebih_cepat<0.5790725326991676', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), confidence=0.9487179487179487, lift=1.5573294629898402), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Aktif_bersama<0.7200328407224957', 'PK>=0.0'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341', 'Lebih_cepat<0.5790725326991676', 'PERFORMANCE<0.021657592256503287', 'LEARNING_POINT<0.0034482758620689655'}), confidence=0.9487179487179487, lift=1.5872781065088755), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Kerja_Ibadah<0.79272030651341', 'LEARNING_POINT<0.0034482758620689655'}), items_add=frozenset({'Aktif_bersama<0.7200328407224957', 'Lebih_cepat<0.5790725326991676', 'PERFORMANCE<0.021657592256503287', 'PK>=0.0'}), confidence=0.9487179487179487, lift=1.6184012066365008), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Kerja_Ibadah<0.79272030651341', 'Lebih_cepat<0.5790725326991676'}), items_add=frozenset({'Aktif_bersama<0.7200328407224957', 'PERFORMANCE<0.021657592256503287', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), confidence=0.9736842105263157, lift=1.6290485829959511), OrderedStatistic(items_base=frozenset({'Apresiasi<0.654181529924693', 'Kerja_Ibadah<0.79272030651341', 'PERFORMANCE<0.021657592256503287'}), items_add=frozenset({'Aktif_bersama<0.7200328407224957', 'Lebih_cepat<0.5790725326991676', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), confid ...
# RelationRecord(items=frozenset({'COMPETENCY<0.4225828262339418', 'Lebih_cepat<0.5790725326991676', 'Kerja_Ibadah<0.79272030651341', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0', 'PERFORMANCE<0.021657592256503287', 'Aktif_bersama<0.7200328407224957'}), support=0.47126436781609193, ordered_statistics=[OrderedStatistic(items_base=frozenset({'COMPETENCY<0.4225828262339418', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676', 'Kerja_Ibadah<0.79272030651341', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0', 'PERFORMANCE<0.021657592256503287'}), confidence=0.9318181818181817, lift=1.559003496503496), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0', 'PERFORMANCE<0.021657592256503287', 'Aktif_bersama<0.7200328407224957'}), confidence=0.911111111111111, lift=1.5542483660130717), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Lebih_cepat<0.5790725326991676', 'PERFORMANCE<0.021657592256503287', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), confidence=1.0, lift=1.4745762711864407), OrderedStatistic(items_base=frozenset({'LEARNING_POINT<0.0034482758620689655', 'COMPETENCY<0.4225828262339418', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341', 'Lebih_cepat<0.5790725326991676', 'PERFORMANCE<0.021657592256503287', 'PK>=0.0'}), confidence=0.9318181818181817, lift=1.559003496503496), OrderedStatistic(items_base=frozenset({'COMPETENCY<0.4225828262339418', 'Lebih_cepat<0.5790725326991676', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341', 'PERFORMANCE<0.021657592256503287', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), confidence=0.9534883720930232, lift=1.508245243128964), OrderedStatistic(items_base=frozenset({'COMPETENCY<0.4225828262339418', 'PERFORMANCE<0.021657592256503287', 'Aktif_bersama<0.7200328407224957'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341', 'Lebih_cepat<0.5790725326991676', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), confidence=0.9318181818181817, lift=1.5295883361921094), OrderedStatistic(items_base=frozenset({'COMPETENCY<0.4225828262339418', 'Aktif_bersama<0.7200328407224957', 'PK>=0.0'}), items_add=frozenset({'Kerja_Ibadah<0.79272030651341', 'Lebih_cepat<0.5790725326991676', 'PERFORMANCE<0.021657592256503287', 'LEARNING_POINT<0.0034482758620689655'}), confidence=0.9318181818181817, lift=1.559003496503496), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418', 'LEARNING_POINT<0.0034482758620689655'}), items_add=frozenset({'Aktif_bersama<0.7200328407224957', 'Lebih_cepat<0.5790725326991676', 'PERFORMANCE<0.021657592256503287', 'PK>=0.0'}), confidence=0.911111111111111, lift=1.5542483660130717), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418', 'Lebih_cepat<0.5790725326991676'}), items_add=frozenset({'Aktif_bersama<0.7200328407224957', 'PERFORMANCE<0.021657592256503287', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), confidence=0.9534883720930232, lift=1.5952593917710194), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418', 'PERFORMANCE<0.021657592256503287'}), items_add=frozenset({'Aktif_bersama<0.7200328407224957', 'Lebih_cepat<0.5790725326991676', 'LEARNING_POINT<0.0034482758620689655', 'PK>=0.0'}), confidence=0.911111111111111, lift=1.5542483660130717), OrderedStatistic(items_base=frozenset({'Kerja_Ibadah<0.79272030651341', 'COMPETENCY<0.4225828262339418', 'PK>=0.0'}), items_add=frozenset({'Aktif_bersama<0.7200328407224957', 'Lebih_cepat<0.5790725326991676', 'PERFORMANCE<0.021657592256503287', 'LEARNING_POINT<0.0034482758620 ...

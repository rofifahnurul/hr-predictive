# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
source1 = r'/content/gdrive/MyDrive/skripsi/master-data-clean.csv'
master = pd.read_csv(source1)
master
# Out:
#           NO        NIK              BUSINESS_UNIT            JOB_LEVEL  \
# 0        1.0  200700326  PT. HADJI KALLA (HOLDING)    EXECUTIVE LEADERS
# 1        2.0  199500085  PT. HADJI KALLA (HOLDING)    EXECUTIVE LEADERS
# 2        3.0  199500048  PT. HADJI KALLA (HOLDING)    EXECUTIVE LEADERS
# 3        4.0  200700297  PT. HADJI KALLA (HOLDING)    EXECUTIVE LEADERS
# 4        5.0  201600670  PT. HADJI KALLA (HOLDING)    EXECUTIVE LEADERS
# ...      ...        ...                        ...                  ...
# 1340  1483.0  201000393       PT. KALLA INTI KARSA       STAFF/OPERATOR
# 1341  1484.0  200800348       PT. KALLA INTI KARSA       STAFF/OPERATOR
# 1342  1485.0  200100421       PT. KALLA INTI KARSA    STRATEGIC LEADERS
# 1343  1486.0  199500919       PT. KALLA INTI KARSA  OPERATIONAL LEADERS
# 1344  1487.0  201929411       PT. KALLA INTI KARSA  OPERATIONAL LEADERS
#
#                             LOCATION                   DEPARTMENT  \
# ...

# %%
source = r'/content/gdrive/MyDrive/skripsi/hasil-cluster1.csv'
cluster1 = pd.read_csv(source)

# %%
cluster1
# Out:
#            NIK        PK  PERFORMANCE  COMPETENCY  LEARNING POINT  \
# 0    201600647  0.970874     0.936842    0.470588            1.00
# 1    201903571  0.970874     0.936842    0.382353            1.00
# 2    201903198  0.970874     0.926316    0.235294            1.00
# 3    201800932  0.970874     0.936842    0.500000            1.00
# 4    201500608  0.970874     0.915789    0.411765            1.00
# ..         ...       ...          ...         ...             ...
# 158  201800934  0.970874     0.936842    0.441176            0.70
# 159  200100216  0.951456     0.894737    0.235294            1.00
# 160  200000197  0.902913     0.863158    0.500000            0.70
# 161  201000393  0.961165     0.884211    0.441176            0.58
# 162  201929411  0.902913     0.863158    0.205882            1.00
#
#      Kerja Ibadah  Apresiasi  Lebih cepat  Aktif bersama  Cluster
# 0        0.866667   0.620690     0.655172       0.589286        1
# ...

# %%
cluster1.describe()
# Out:
#                 NIK          PK  PERFORMANCE  COMPETENCY  LEARNING POINT  \
# count  1.630000e+02  163.000000   163.000000  163.000000      163.000000
# mean   2.011585e+08    0.925487     0.880982    0.424396        0.886196
# std    8.658951e+05    0.055426     0.053920    0.140294        0.198750
# min    1.972906e+08    0.669903     0.621053    0.058824        0.000000
# 25%    2.009409e+08    0.902913     0.852632    0.352941        0.800000
# 50%    2.014006e+08    0.941748     0.894737    0.441176        1.000000
# 75%    2.018009e+08    0.970874     0.915789    0.500000        1.000000
# max    2.021913e+08    0.970874     0.957895    0.852941        1.000000
#
#        Kerja Ibadah   Apresiasi  Lebih cepat  Aktif bersama  Cluster
# count    163.000000  163.000000   163.000000     163.000000    163.0
# mean       0.823654    0.682357     0.643220       0.664001      1.0
# std        0.130591    0.145328     0.151781       0.170834      0.0
# ...

# %%
mergedCSV = master[['NIK','BUSINESS_UNIT','LOCATION','DEPARTMENT','JOB_POSITION','JOB_LEVEL']].merge(cluster1, on = 'NIK',how = 'right')
mergedCSV
# Out:
#            NIK              BUSINESS_UNIT                        LOCATION  \
# 0    201600647  PT. HADJI KALLA (HOLDING)         HEAD OFFICE COKRO LT. 2
# 1    201903571  PT. HADJI KALLA (HOLDING)         HEAD OFFICE COKRO LT. 2
# 2    201903198  PT. HADJI KALLA (HOLDING)         HEAD OFFICE COKRO LT. 2
# 3    201800932  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 14
# 4    201500608  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 14
# ..         ...                        ...                             ...
# 158  201800934       PT. KALLA INTI KARSA                      NIPAH MALL
# 159  200100216       PT. KALLA INTI KARSA                     WISMA KALLA
# 160  200000197       PT. KALLA INTI KARSA                     WISMA KALLA
# 161  201000393       PT. KALLA INTI KARSA                     WISMA KALLA
# 162  201929411       PT. KALLA INTI KARSA                     WISMA KALLA
#
#                                       DEPARTMENT  \
# ...

# %%
mergedCSV['BUSINESS_UNIT'].unique()
# Out:
# array(['PT. HADJI KALLA (HOLDING)', 'PT. BUMI KARSA',
#        'PT. BUMI SARANA UTAMA', 'PT. BUMI SARANA BETON',
#        'PT. KALLA INTI KARSA'], dtype=object)

# %%
for i in mergedCSV['BUSINESS_UNIT'].unique():
  print(i, len(mergedCSV.loc[mergedCSV['BUSINESS_UNIT'] == i]))
# Out:
# PT. HADJI KALLA (HOLDING) 49
# PT. BUMI KARSA 34
# PT. BUMI SARANA UTAMA 24
# PT. BUMI SARANA BETON 17
# PT. KALLA INTI KARSA 39

# %%
for i in mergedCSV['DEPARTMENT'].unique():
  print(i, len(mergedCSV.loc[mergedCSV['DEPARTMENT'] == i]))
# Out:
# ASSESSMENT CENTER & COMPETENCY DEPARTMENT 3
# ASSET MANAGEMENT STANDARDIZATION DEPARTMENT 3
# BUSINESS DEVELOPMENT & SYNERGY DEVCON DEPARTMENT 1
# BUSINESS DEVELOPMENT & SYNERGY OTO DIVISION 3
# CORP. INFORMATION, COMMUNICATION & TECHNOLOGY DIVISION 1
# CORP. PERFORMANCE & CULTURE DIVISION 1
# CORPORATE COMMUNICATION DEPARTMENT 1
# CORPORATE CULTURE DEPARTMENT 1
# CORPORATE LEGAL DEPARTMENT 2
# CORPORATE MARKETING SERVICES DEPARTMENT 2
# CORPORATE SOCIAL RESPONSIBILITY DEPARTMENT 1
# EXTERNAL RELATION DEPARTMENT 2
# HC SHARED SERVICES DEPARTMENT 1
# INTERNAL AUDIT & RISK MANAGEMENT DIVISION 1
# INTERNAL AUDIT DEPARTMENT 10
# KNOWLEDGE MANAGEMENT DEPARTMENT 1
# LEARNING & DEVELOPMENT DIVISION 1
# MARKETING RESEARCH & CUSTOMER INSIGHT DEPARTMENT 1
# PEOPLE STRATEGY & POLICY DIVISION 1
# QUALITY CONSOLIDATION DEPARTMENT 1
# QUALITY SYSTEM & SUPPLY CHAIN MANAGEMENT DIVISION 1
# RISK MANAGEMENT DEPARTMENT 3
# SUPPLY CHAIN MANAGEMENT DEPARTMENT 3
# TALENT MANAGEMENT DEPARTMENT 1
# ...

# %%
for i in mergedCSV['JOB_POSITION'].unique():
  print(i, len(mergedCSV.loc[mergedCSV['JOB_POSITION'] == i]))
# Out:
# ASSESSMENT CENTER ASSOCIATES 1
# ASSESSMENT CENTER SENIOR ANALYST 2
# BUILDING & FACILITIES STANDARDIZATION OFFICER 3
# PJS. BUSINESS DEVELOPMENT ASSOCIATES 1
# BUSINESS DEVELOPMENT & SYNERGY DIVISION HEAD 1
# BUSINESS DEVELOPMENT & SYNERGY ASSOCIATES 2
# CORP. INFORMATION, COMMUNICATION & TECHNOLOGY DIVISION HEAD 1
# PJS. CORPORATE PERFORMANCE & EVALUATION SENIOR ASSOCIATES 1
# CORPORATE COMMUNICATION OFFICER 1
# CORPORATE CULTURE OFFICER 1
# CORPORATE LEGAL DEPARTMENT HEAD 1
# LITIGATION SENIOR OFFICER 1
# CORPORATE MARKETING SERVICES DEPARTMENT HEAD 1
# DATA MANAGEMENT SENIOR ANALYST 1
# CORPORATE SOCIAL RESPONSIBILITY SPECIALIST 1
# EXTERNAL RELATION SENIOR ASSOCIATES 1
# PJS. EXTERNAL RELATION SENIOR ASSOCIATES 1
# PJS. HC SHARED SERVICES DEPARTMENT HEAD 1
# INTERNAL AUDIT & RISK MANAGEMENT DIVISION HEAD 1
# INTERNAL AUDIT OFFICER 5
# INTERNAL AUDIT SENIOR OFFICER 1
# MONITORING & FOLLOW UP SENIOR OFFICER 1
# INTERNAL AUDIT JUNIOR OFFICER 3
# ...

# %%
mergedCSV.describe()
# Out:
#                 NIK          PK  PERFORMANCE  COMPETENCY  LEARNING POINT  \
# count  1.630000e+02  163.000000   163.000000  163.000000      163.000000
# mean   2.011585e+08    0.925487     0.880982    0.424396        0.886196
# std    8.658951e+05    0.055426     0.053920    0.140294        0.198750
# min    1.972906e+08    0.669903     0.621053    0.058824        0.000000
# 25%    2.009409e+08    0.902913     0.852632    0.352941        0.800000
# 50%    2.014006e+08    0.941748     0.894737    0.441176        1.000000
# 75%    2.018009e+08    0.970874     0.915789    0.500000        1.000000
# max    2.021913e+08    0.970874     0.957895    0.852941        1.000000
#
#        Kerja Ibadah   Apresiasi  Lebih cepat  Aktif bersama  Cluster
# count    163.000000  163.000000   163.000000     163.000000    163.0
# mean       0.823654    0.682357     0.643220       0.664001      1.0
# std        0.130591    0.145328     0.151781       0.170834      0.0
# ...

# %% [markdown]
# # ***Cluster 2***

# %%
source = r'/content/gdrive/MyDrive/skripsi/hasil-cluster2.csv'
cluster2 = pd.read_csv(source)
cluster2
# Out:
#            NIK        PK  PERFORMANCE  COMPETENCY  LEARNING POINT  \
# 0    201700733  0.961165     0.947368    0.823529             1.0
# 1    201801023  0.951456     0.947368    0.617647             1.0
# 2    201903269  0.961165     0.926316    0.588235             1.0
# 3    202104089  0.970874     0.947368    0.676471             1.0
# 4    201600660  0.970874     0.957895    0.529412             1.0
# ..         ...       ...          ...         ...             ...
# 523  201200662  0.970874     0.947368    0.882353             1.0
# 524  201100495  0.961165     0.926316    0.470588             0.5
# 525  200900350  0.970874     0.947368    0.911765             1.0
# 526  200800348  0.902913     0.884211    0.882353             1.0
# 527  200100421  0.883495     0.852632    0.735294             1.0
#
#      Kerja Ibadah  Apresiasi  Lebih cepat  Aktif bersama  Cluster
# 0        0.955556   1.000000     1.000000       1.000000        2
# ...

# %%
mergedCSV2 = master[['NIK','BUSINESS_UNIT','LOCATION','DEPARTMENT','JOB_POSITION','JOB_LEVEL']].merge(cluster2, on = 'NIK',how = 'right')
mergedCSV2
# Out:
#            NIK              BUSINESS_UNIT                        LOCATION  \
# 0    201700733  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 14
# 1    201801023  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 14
# 2    201903269  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 14
# 3    202104089  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 14
# 4    201600660  PT. HADJI KALLA (HOLDING)         HEAD OFFICE COKRO LT. 2
# ..         ...                        ...                             ...
# 523  201200662       PT. KALLA INTI KARSA                     WISMA KALLA
# 524  201100495       PT. KALLA INTI KARSA                     WISMA KALLA
# 525  200900350       PT. KALLA INTI KARSA                     WISMA KALLA
# 526  200800348       PT. KALLA INTI KARSA                     WISMA KALLA
# 527  200100421       PT. KALLA INTI KARSA                     WISMA KALLA
#
#                                     DEPARTMENT  \
# ...

# %%
mergedCSV2.describe()
# Out:
#                 NIK          PK  PERFORMANCE  COMPETENCY  LEARNING POINT  \
# count  5.280000e+02  528.000000   528.000000  528.000000      528.000000
# mean   2.011393e+08    0.937757     0.917464    0.615363        0.922860
# std    8.492258e+05    0.048611     0.047852    0.179540        0.149566
# min    1.982000e+08    0.485437     0.484211    0.176471        0.450000
# 25%    2.008980e+08    0.922330     0.905263    0.441176        0.950000
# 50%    2.013906e+08    0.951456     0.926316    0.588235        1.000000
# 75%    2.017908e+08    0.970874     0.947368    0.764706        1.000000
# max    2.021913e+08    1.000000     1.000000    1.000000        1.000000
#
#        Kerja Ibadah   Apresiasi  Lebih cepat  Aktif bersama  Cluster
# count    528.000000  528.000000   528.000000     528.000000    528.0
# mean       0.949095    0.951443     0.919214       0.947004      2.0
# std        0.062788    0.068445     0.086477       0.074157      0.0
# ...

# %%
for i in mergedCSV2['BUSINESS_UNIT'].unique():
  print(i, len(mergedCSV2.loc[mergedCSV2['BUSINESS_UNIT'] == i]))
# Out:
# PT. HADJI KALLA (HOLDING) 182
# PT. BUMI KARSA 169
# PT. BUMI SARANA UTAMA 48
# PT. BUMI SARANA BETON 58
# PT. KALLA INTI KARSA 71

# %%
for i in mergedCSV2['LOCATION'].unique():
  print(i, len(mergedCSV2.loc[mergedCSV2['LOCATION'] == i]))
# Out:
# HEAD OFFICE WISMA KALLA LT. 14 51
# HEAD OFFICE COKRO LT. 2 14
# HEAD OFFICE WISMA KALLA LT. 13 71
# NIPAH MALL 18
# HEAD OFFICE WISMA KALLA LT. 3 43
# HEADQUARTERS 44
# HEAD OFFICE 55
# PROYEK BATANG ASAI 4
# PROYEK BENDUNG BUDONG BUDONG MAMUJU 3
# PROYEK IRIGASI BALIASE KIRI LUWU UTARA 1
# PROYEK IRIGASI PAMANUKAN SUBANG 3
# PROYEK IRIGASI RENTANG LS004 7
# PROYEK IRIGASI RENTANG LS008 4
# PROYEK JALAN MAJENE-POLEWALI 6
# PROYEK PEMBANGUNAN BENDUNGAN BOLANGO ULU 4
# PROYEK PEMBANGUNAN MASJID RAYA BONE 2
# PROYEK PRESERVASI JALAN SINJAI-WATAMPONE 6
# PROYEK SAMBERA 7
# PROYEK STASIUN KA 4
# PROYEK SUNGAI BOGOWONTO YOGYAKARTA 5
# REPRESENTATIVE OFFICE 3
# PENGENDALIAN BANJIR KALI BEKASI PAKET 6 4
# PERALATAN PROYEK BENDUNG BOLANGO 2
# PLANT MAROS-BONE(CAMBA) 1
# PROYEK JALAN YETTI MAMBERAMO 7
# PROYEK PENG SUNGAI BOLANGO GORONTALO 4
# PROYEK PERKERETAAPIAN MKS-PAREPARE SEGMEN F 1
# PROYEK REVITALISASI DANAU TONDANO TAHAP I 3
# PROYEK TANAH GROGOT 3
# UNIT 13
# PLANT BILA SIDRAP 1
# ...

# %%
for i in mergedCSV2['DEPARTMENT'].unique():
  print(i, len(mergedCSV2.loc[mergedCSV2['DEPARTMENT'] == i]))
# Out:
# ACCOUNTING CONSOLE DEPARTMENT 4
# ASSESSMENT CENTER & COMPETENCY DEPARTMENT 1
# ASSET MANAGEMENT STANDARDIZATION DEPARTMENT 3
# BUDGET CONTROL & TAX  DEVCON DEPARTMENT 2
# BUDGET CONTROL & TAX  OTO DEPARTMENT 3
# BUSINESS DEVELOPMENT & EVALUATION DEPARTMENT 2
# BUSINESS DEVELOPMENT & SYNERGY DEVCON DEPARTMENT 4
# BUSINESS DEVELOPMENT & SYNERGY OTO DIVISION 2
# BUSINESS DEVELOPMENT DIVISION 1
# CORP. PERFORMANCE & CULTURE DIVISION 3
# CORPORATE COMMUNICATION DEPARTMENT 9
# CORPORATE CULTURE DEPARTMENT 2
# CORPORATE FINANCE DEPARTMENT 6
# CORPORATE FINANCE, ACCOUNTING & TAX DIVISION 1
# CORPORATE LEGAL DEPARTMENT 3
# CORPORATE MARKETING SERVICES DEPARTMENT 7
# CORPORATE SOCIAL RESPONSIBILITY DEPARTMENT 1
# DATA & APPLICATION SOLUTION DEPARTMENT 9
# FINANCE & ACCOUNTING OPERATION HOLDING & HSI DEPARTMENT 5
# FINANCE OPERATION DEVCON DIVISION 1
# FINANCE OPERATION OTO DIVISION 1
# GA, HSE, PURCHASING & SECRETARY HOLDING DEPARTMENT 4
# GENERAL COUNSEL DIVISION 1
# ...

# %%
for i in mergedCSV2['JOB_POSITION'].unique():
  print(i, len(mergedCSV2.loc[mergedCSV2['JOB_POSITION'] == i]))
# Out:
# PJS. ACCOUNTING CONSOLE DEPARTMENT HEAD 1
# ACCOUNTING CONSOLE OFFICER 2
# ACCOUNTING CONSOLE JUNIOR OFFICER 1
# ASSESSMENT CENTER & COMPETENCY DEPARTMENT HEAD 1
# ASSET MANAGEMENT STANDARDIZATION DEPARTMENT HEAD 1
# BUILDING & FACILITIES STANDARDIZATION SENIOR OFFICER 1
# LANDBANK ASSET MANAGEMENT ASSOCIATES 1
# PJS. BUDGET CONTROL & TAX DEPARTMENT HEAD 1
# BUDGET CONTROL & TAX SENIOR ANALYST 1
# BUDGET CONTROL & TAX DEPARTMENT HEAD 1
# BUDGET CONTROL SENIOR OFFICER 1
# TAX SENIOR OFFICER 1
# BUSINESS DEVELOPMENT & EVALUATION DEPARTMENT HEAD 1
# BUSINESS DEVELOPMENT & EVALUATION OFFICER 1
# BUSINESS DEVELOPMENT & SYNERGY DEPARTMENT HEAD 1
# BUSINESS DEVELOPMENT & SYNERGY ASSOCIATES 3
# BUSINESS DEVELOPMENT & SYNERGY SENIOR ANALYST 1
# BUSINESS DEVELOPMENT & SYNERGY SENIOR ASSOCIATES 1
# BUSINESS DEVELOPMENT DIVISION HEAD 1
# CORP. PERFORMANCE & CULTURE DIVISION HEAD 1
# PJS. CORPORATE PERFORMANCE & EVALUATION SENIOR ASSOCIATES 1
# CORPORATE PERFORMANCE & EVALUATION SENIOR ANALYST 1
# ...

# %%
for i in mergedCSV2['JOB_LEVEL'].unique():
  print(i, len(mergedCSV2.loc[mergedCSV2['JOB_LEVEL'] == i]))
# Out:
# OPERATIONAL LEADERS 94
# TECHNICAL LEADERS 242
# STAFF/OPERATOR 175
# STRATEGIC LEADERS 15
# EXECUTIVE LEADERS 2

# %% [markdown]
# ## ***Cluster 3***

# %%
source = r'/content/gdrive/MyDrive/skripsi/hasil-cluster3.csv'
cluster3 = pd.read_csv(source)
cluster3
# Out:
#            NIK        PK  PERFORMANCE  COMPETENCY  LEARNING POINT  \
# 0    200700326  0.970874     0.957895    0.676471             0.0
# 1    199500085  0.902913     0.863158    0.470588             0.0
# 2    199500048  0.883495     0.915789    0.558824             0.0
# 3    200700297  0.951456     0.968421    0.794118             0.0
# 4    201600670  0.873786     0.957895    0.470588             0.0
# ..         ...       ...          ...         ...             ...
# 553  201000471  0.902913     0.873684    0.411765             0.0
# 554  201000430  0.902913     0.873684    0.411765             0.0
# 555  201000431  0.902913     0.863158    0.588235             0.0
# 556  202104021  0.902913     0.863158    0.617647             0.2
# 557  199500919  0.902913     0.873684    0.676471             0.0
#
#      Kerja Ibadah  Apresiasi  Lebih cepat  Aktif bersama  Cluster
# 0        0.944444   0.965517     0.896552       0.767857        3
# ...

# %%
len(cluster3['NIK'].unique())
# Out:
# 558

# %%
mergedCSV3 = mergedCSV3.drop_duplicates(keep='first')

# %%
len(mergedCSV3['NIK'].unique())
# Out:
# 558

# %%
mergedCSV3.loc[mergedCSV3['Cluster'] == '']
# Out:
# Empty DataFrame
# Columns: [NIK, BUSINESS_UNIT, LOCATION, DEPARTMENT, JOB_POSITION, JOB_LEVEL, PK, PERFORMANCE, COMPETENCY, LEARNING POINT, Kerja Ibadah, Apresiasi, Lebih cepat, Aktif bersama, Cluster]
# Index: []

# %%
duplicate = mergedCSV3[mergedCSV3.duplicated('NIK')]
 
print("Duplicate Rows based on NIK :",duplicate)
# Out:
# Duplicate Rows based on NIK : Empty DataFrame
# Columns: [NIK, BUSINESS_UNIT, LOCATION, DEPARTMENT, JOB_POSITION, JOB_LEVEL, PK, PERFORMANCE, COMPETENCY, LEARNING POINT, Kerja Ibadah, Apresiasi, Lebih cepat, Aktif bersama, Cluster]
# Index: []

# %%
duplicate = cluster3[cluster3.duplicated('NIK')]
 
print("Duplicate Rows based on NIK :",duplicate)
# Out:
# Duplicate Rows based on NIK : Empty DataFrame
# Columns: [NIK, PK, PERFORMANCE, COMPETENCY, LEARNING POINT, Kerja Ibadah, Apresiasi, Lebih cepat, Aktif bersama, Cluster]
# Index: []

# %%
mergedCSV3 = master[['NIK','BUSINESS_UNIT','LOCATION','DEPARTMENT','JOB_POSITION','JOB_LEVEL']].merge(cluster3, on = 'NIK',how = 'right')
mergedCSV3
# Out:
#            NIK              BUSINESS_UNIT                        LOCATION  \
# 0    200700326  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 13
# 1    199500085  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 13
# 2    199500048  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 14
# 3    200700297  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 13
# 4    201600670  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 13
# ..         ...                        ...                             ...
# 553  201000471       PT. KALLA INTI KARSA                     WISMA KALLA
# 554  201000430       PT. KALLA INTI KARSA                     WISMA KALLA
# 555  201000431       PT. KALLA INTI KARSA                     WISMA KALLA
# 556  202104021       PT. KALLA INTI KARSA                     WISMA KALLA
# 557  199500919       PT. KALLA INTI KARSA                     WISMA KALLA
#
#                       DEPARTMENT                               JOB_POSITION  \
# ...

# %%
duplicate = mergedCSV3[mergedCSV3.duplicated('NIK')]
 
print("Duplicate Rows based on NIK :",duplicate)
# Out:
# Duplicate Rows based on NIK : Empty DataFrame
# Columns: [NIK, BUSINESS_UNIT, LOCATION, DEPARTMENT, JOB_POSITION, JOB_LEVEL, PK, PERFORMANCE, COMPETENCY, LEARNING POINT, Kerja Ibadah, Apresiasi, Lebih cepat, Aktif bersama, Cluster]
# Index: []

# %%
mergedCSV3.describe()
# Out:
#                 NIK          PK  PERFORMANCE  COMPETENCY  LEARNING POINT  \
# count  5.580000e+02  558.000000   558.000000  558.000000      558.000000
# mean   2.009531e+08    0.906967     0.872213    0.508539        0.077437
# std    9.598677e+05    0.061400     0.048885    0.165578        0.137687
# min    1.979905e+08    0.000000     0.557895    0.000000        0.000000
# 25%    2.004002e+08    0.883495     0.852632    0.411765        0.000000
# 50%    2.012006e+08    0.912621     0.884211    0.411765        0.000000
# 75%    2.016008e+08    0.941748     0.905263    0.588235        0.120000
# max    2.021915e+08    0.970874     0.968421    0.941176        0.500000
#
#        Kerja Ibadah   Apresiasi  Lebih cepat  Aktif bersama  Cluster
# count    558.000000  558.000000   558.000000     558.000000    558.0
# mean       0.903405    0.877765     0.825701       0.872856      3.0
# std        0.114057    0.166023     0.197301       0.162665      0.0
# ...

# %%
for i in mergedCSV3['BUSINESS_UNIT'].unique():
  print(i, len(mergedCSV3.loc[mergedCSV3['BUSINESS_UNIT'] == i]))
# Out:
# PT. HADJI KALLA (HOLDING) 11
# PT. BUMI KARSA 161
# PT. BUMI SARANA UTAMA 249
# PT. BUMI SARANA BETON 94
# PT. KALLA INTI KARSA 43

# %%
for i in mergedCSV3['DEPARTMENT'].unique():
  print(i, len(mergedCSV3.loc[mergedCSV3['DEPARTMENT'] == i]))
# Out:
# DIRECTOR 11
# GA, HSE, PURCHASING & SECRETARY HOLDING DEPARTMENT 2
# TREASURY & ASET MANAGEMENT DIVISION 1
# GENERAL AFFAIR DEPARTMENT 1
# PLANNING, RESEARCH & DEVELOPMENT DEPARTMENT 1
# PROJECT DEPARTMENT 33
# JO/JVC/POOL DEPARTMENT 4
# EQUIPMENT DEPARTMENT 137
# ACCOUNTING DEPARTMENT 3
# NON-STAF 1
# QMS & HSE DEPARTMENT 1
# FINANCE DEPARTMENT 4
# HCBP, GA, & HSE DEPARTMENT 1
# LEGAL 2
# PURCHASING DEPARTMENT 1
# BRANCH BANJARMASIN 23
# BRANCH BULUNGAN 16
# BRANCH GORONTALO 27
# BRANCH JAYAPURA 17
# BRANCH KENDARI 24
# BRANCH LOMBOK 11
# BRANCH MAKASSAR 39
# BRANCH PALU 25
# BRANCH PONTIANAK 12
# BRANCH SAMARINDA 24
# BRANCH SORONG 16
# TAC PAGIMANA 10
# BATA RINGAN DEPARTMENT 8
# HCBP, GA & HSE DEPARTMENT 2
# PRECAST DEPARTMENT 8
# PROCUREMENT DEPARTMENT 10
# QSO 2
# READY MIX DEPARTMENT 36
# SALES DEPARTMENT 1
# SMO 2
# SUPPLY CHAIN 1
# MARI SHOPPING CENTRE 17
# NIPAH OFFICE & SHOPPING CENTRE 15
# WISMA KALLA OFFICE BUILDING 8
# FOOD & BEVERAGE 1

# %%
for i in mergedCSV3['LOCATION'].unique():
  print(i, len(mergedCSV3.loc[mergedCSV3['LOCATION'] == i]))
# Out:
# HEAD OFFICE WISMA KALLA LT. 13 7
# HEAD OFFICE WISMA KALLA LT. 14 4
# HEADQUARTERS 17
# PROYEK JALAN YETTI MAMBERAMO 1
# PROYEK STASIUN KA 2
# UNIT 8
# HEAD OFFICE 14
# PENGENDALIAN BANJIR KALI BEKASI PAKET 6 2
# PERALATAN PROYEK BENDUNG BOLANGO 13
# PLANT GROGOT 9
# PLANT KAMPIRI 5
# PLANT MAROS-BONE(CAMBA) 5
# PLANT PAPUA 17
# PLANT PINRANG 21
# PLANT SAMBERA 14
# PLANT SINJAI-WATAMPONE 3
# PROYEK BATANG ASAI 5
# PROYEK IRIGASI RENTANG LS004 3
# PROYEK IRIGASI RENTANG LS008 2
# PROYEK PEMBANGUNAN BENDUNGAN BOLANGO ULU 2
# PROYEK PERKERETAAPIAN MKS-PAREPARE SEGMEN F 2
# PROYEK RENOVASI SHOW ROOM DAN BENGKEL PT. HADJI KALLA CABANG BONE 1
# PROYEK REVITALISASI DANAU TONDANO TAHAP I 4
# PROYEK SAMBERA 3
# PROYEK SUBKON QUARRY MARDINDING JAHE 2
# PROYEK SUNGAI BOGOWONTO YOGYAKARTA 1
# PROYEK TANAH GROGOT 3
# REPRESENTATIVE OFFICE 1
# PROYEK IRIGASI BALIASE KIRI LUWU UTARA 1
# PROYEK JALAN MAJENE-POLEWALI 1
# PROYEK PRESERVASI JALAN SINJAI-WATAMPONE 1
# HEAD OFFICE WISMA KALLA LT. 10 5
# ...

# %%
for i in mergedCSV3['JOB_POSITION'].unique():
  print(i, len(mergedCSV3.loc[mergedCSV3['JOB_POSITION'] == i]))
# Out:
# CHIEF EXECUTIVE OFFICER GO DEVCON 1
# CHIEF FINANCE OFFICER  KALLA OTO 1
# CORPORATE FINANCE DIRECTOR 1
# MARKETING & BUSINESS DEVELOPMENT DIRECTOR 1
# PEOPLE & PERFORMANCE DIRECTOR 1
# PRESIDENT DIRECTOR 1
# CHIEF CORPORATE SECRETARY & LEGAL OFFICER 1
# CHIEF FINANCE OFFICER KALLA DEVCON 1
# SUPPORTING (OFFICE BOY) 1
# SUPPORTING (OFFICE GIRL) 1
# TREASURY & ASET MANAGEMENT DIVISION HEAD 1
# GENERAL AFFAIR MANAGER 1
# PLANNING, RESEARCH & DEVELOPMENT MANAGER 1
# KEPALA PROYEK 2
# DIREKTUR TEKNIK 1
# MANAGER ENGINEERING 1
# MANAGER LOGISTIC 1
# EQUIPMENT EVALUATION & ERP SENIOR STAFF 1
# EQUIPMENT MOBILIZATION SENIOR STAFF 1
# EQUIPMENT ORDER SENIOR STAF 1
# MECHANIC 6
# MEKANIK BUBUT 1
# MEKANIK ELEKTRISI 6
# MEKANIK LAS 6
# OPERATOR ALAT BERAT 35
# AKUNTANSI PROYEK STAFF 2
# KEPALA PERALATAN 2
# SOPIR ALAT ANGKUT 44
# OFFICE DRIVER 1
# ENGINEER BUSINESS DEVELOPMENT STAFF 1
# ERP SENIOR STAFF 1
# WORKSHOP ADMINISTRATION SENIOR STAFF 1
# PLANT ADMINISTRATION STAFF 5
# ...

# %%
for i in mergedCSV3['JOB_LEVEL'].unique():
  print(i, len(mergedCSV3.loc[mergedCSV3['JOB_LEVEL'] == i]))
# Out:
# EXECUTIVE LEADERS 8
# STRATEGIC LEADERS 4
# STAFF/OPERATOR 419
# OPERATIONAL LEADERS 13
# TECHNICAL LEADERS 71
# NON STAFF 43

# %% [markdown]
# ## **Cluster 4**

# %%
source = r'/content/gdrive/MyDrive/skripsi/hasil-cluster4.csv'
cluster4 = pd.read_csv(source)
cluster4
# Out:
#           NIK   PK  PERFORMANCE  COMPETENCY  LEARNING POINT  Kerja Ibadah  \
# 0   201791264  0.0     0.000000    0.441176             0.0      0.722222
# 1   201791265  0.0     0.000000    0.411765             0.0      0.744444
# 2   201791266  0.0     0.042105    0.411765             0.0      0.911111
# 3   201791262  0.0     0.031579    0.558824             0.0      0.911111
# 4   201791261  0.0     0.000000    0.441176             0.0      0.733333
# ..        ...  ...          ...         ...             ...           ...
# 82  199691301  0.0     0.000000    0.264706             0.0      0.722222
# 83  201191172  0.0     0.000000    0.264706             0.0      0.700000
# 84  200891138  0.0     0.000000    0.411765             0.0      0.655556
# 85  200391120  0.0     0.010526    0.411765             0.0      0.811111
# 86  201291193  0.0     0.010526    0.411765             0.0      0.688889
#
#     Apresiasi  Lebih cepat  Aktif bersama  Cluster
# ...

# %%
cluster4.describe()
# Out:
#                 NIK    PK  PERFORMANCE  COMPETENCY  LEARNING POINT  \
# count  8.700000e+01  87.0    87.000000   87.000000       87.000000
# mean   2.012130e+08   0.0     0.021658    0.422583        0.003448
# std    4.954600e+05   0.0     0.092429    0.153296        0.032163
# min    1.992913e+08   0.0     0.000000    0.088235        0.000000
# 25%    2.009412e+08   0.0     0.000000    0.411765        0.000000
# 50%    2.012912e+08   0.0     0.010526    0.411765        0.000000
# 75%    2.014912e+08   0.0     0.021053    0.426471        0.000000
# max    2.019913e+08   0.0     0.863158    0.911765        0.300000
#
#        Kerja Ibadah  Apresiasi  Lebih cepat  Aktif bersama  Cluster
# count     87.000000  87.000000    87.000000      87.000000     87.0
# mean       0.792720   0.654182     0.579073       0.720033      4.0
# std        0.095549   0.195760     0.184735       0.153408      0.0
# min        0.655556   0.327586     0.241379       0.482143      4.0
# ...

# %%
mergedCSV4 = master[['NIK','BUSINESS_UNIT','LOCATION','DEPARTMENT','JOB_POSITION','JOB_LEVEL']].merge(cluster4, on = 'NIK',how = 'right')
mergedCSV4
# Out:
#           NIK          BUSINESS_UNIT            LOCATION  \
# 0   201791264  PT. BUMI SARANA BETON        Unit KIMA 17
# 1   201791265  PT. BUMI SARANA BETON        Unit KIMA 17
# 2   201791266  PT. BUMI SARANA BETON        Unit KIMA 17
# 3   201791262  PT. BUMI SARANA BETON        Unit KIMA 17
# 4   201791261  PT. BUMI SARANA BETON        Unit KIMA 17
# ..        ...                    ...                 ...
# 82  199691301  PT. BUMI SARANA BETON  Unit Tanjung Bunga
# 83  201191172  PT. BUMI SARANA BETON  Unit Tanjung Bunga
# 84  200891138  PT. BUMI SARANA BETON  Unit Tanjung Bunga
# 85  200391120  PT. BUMI SARANA BETON  Unit Tanjung Bunga
# 86  201291193  PT. BUMI SARANA BETON  Unit Tanjung Bunga
#
#                 DEPARTMENT           JOB_POSITION  JOB_LEVEL   PK  \
# 0   BATA RINGAN DEPARTMENT  DRIVER FLATBACK TRUCK  NON STAFF  0.0
# 1   BATA RINGAN DEPARTMENT  DRIVER FLATBACK TRUCK  NON STAFF  0.0
# 2   BATA RINGAN DEPARTMENT  DRIVER FLATBACK TRUCK  NON STAFF  0.0
# ...

# %%
mergedCSV4.describe()
# Out:
#                 NIK    PK  PERFORMANCE  COMPETENCY  LEARNING POINT  \
# count  8.700000e+01  87.0    87.000000   87.000000       87.000000
# mean   2.012130e+08   0.0     0.021658    0.422583        0.003448
# std    4.954600e+05   0.0     0.092429    0.153296        0.032163
# min    1.992913e+08   0.0     0.000000    0.088235        0.000000
# 25%    2.009412e+08   0.0     0.000000    0.411765        0.000000
# 50%    2.012912e+08   0.0     0.010526    0.411765        0.000000
# 75%    2.014912e+08   0.0     0.021053    0.426471        0.000000
# max    2.019913e+08   0.0     0.863158    0.911765        0.300000
#
#        Kerja Ibadah  Apresiasi  Lebih cepat  Aktif bersama  Cluster
# count     87.000000  87.000000    87.000000      87.000000     87.0
# mean       0.792720   0.654182     0.579073       0.720033      4.0
# std        0.095549   0.195760     0.184735       0.153408      0.0
# min        0.655556   0.327586     0.241379       0.482143      4.0
# ...

# %%
for i in mergedCSV4['BUSINESS_UNIT'].unique():
  print(i, len(mergedCSV4.loc[mergedCSV4['BUSINESS_UNIT'] == i]))
# Out:
# PT. BUMI SARANA BETON 87

# %%
for i in mergedCSV4['LOCATION'].unique():
  print(i, len(mergedCSV4.loc[mergedCSV4['LOCATION'] == i]))
# Out:
# Unit KIMA 17 28
# Head Office Wisma Kalla 4
# Unit Bontoramba 6
# Unit Tanjung Bunga 21
# Ready Mix Proyek Barru 5
# Ready Mix Proyek Pangkep 2
# Unit Kendari 3
# Unit Lonjoboko 18

# %%
for i in mergedCSV4['JOB_POSITION'].unique():
  print(i, len(mergedCSV4.loc[mergedCSV4['JOB_POSITION'] == i]))
# Out:
# DRIVER FLATBACK TRUCK 3
# LABORAT 3
# OPERATOR AUTOCLAVE 3
# OPERATOR BALLMILL 3
# OPERATOR BOILER 2
# OPERATOR CCR 1
# OPERATOR CUTTING CRANE 3
# OPERATOR FORKLIFT 2
# OPERATOR KAPUR 1
# OPERATOR LOADER 8
# OPERATOR POURING / CURING 2
# OPERATOR POURING/CURING 1
# SECURITY 6
# DRIVER 1
# DRIVER DEPUTY COO 1
# DRIVER OPERASIONAL HEAD OFFICE 1
# OFFICE GIRL 1
# DRIVER DUMP TRUCK 14
# OPERATOR MESIN PRECAST 2
# WAREHOUSE STAFF 2
# DRIVER TRUCK MIXER 14
# OPERATOR CONCRETE PUMP 1
# OPERATOR BATCHING PLANT 1
# CREW STONE CRUSHER 1
# OPERATOR EXCAVATOR 3
# OPERATOR SCALVIN 1
# OPERATOR STONE CRUSHER 3
# KOORDINATOR SHIFT 1
# SURVEYOR 2

# %%
for i in mergedCSV4['DEPARTMENT'].unique():
  print(i, len(mergedCSV4.loc[mergedCSV4['DEPARTMENT'] == i]))
# Out:
# BATA RINGAN DEPARTMENT 27
# HCBP, GA & HSE DEPARTMENT 4
# PRECAST DEPARTMENT 5
# PROCUREMENT DEPARTMENT 2
# READY MIX DEPARTMENT 49

# %%
for i in mergedCSV4['JOB_LEVEL'].unique():
  print(i, len(mergedCSV4.loc[mergedCSV4['JOB_LEVEL'] == i]))
# Out:
# NON STAFF 86
# STAFF/OPERATOR 1

# %% [markdown]
# # ***Best***

# %%
mergedCSV2
# Out:
#            NIK              BUSINESS_UNIT                        LOCATION  \
# 0    201700733  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 14
# 1    201801023  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 14
# 2    201903269  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 14
# 3    202104089  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 14
# 4    201600660  PT. HADJI KALLA (HOLDING)         HEAD OFFICE COKRO LT. 2
# ..         ...                        ...                             ...
# 523  201200662       PT. KALLA INTI KARSA                     WISMA KALLA
# 524  201100495       PT. KALLA INTI KARSA                     WISMA KALLA
# 525  200900350       PT. KALLA INTI KARSA                     WISMA KALLA
# 526  200800348       PT. KALLA INTI KARSA                     WISMA KALLA
# 527  200100421       PT. KALLA INTI KARSA                     WISMA KALLA
#
#                                     DEPARTMENT  \
# ...

# %%
mergedCSV2['perform_without_add'] = (85/100*mergedCSV2['PK']) + (15/100*( mergedCSV2['Kerja Ibadah']+mergedCSV2['Apresiasi']+
         mergedCSV2['Lebih cepat']+mergedCSV2['Aktif bersama']))

# %%
mergedCSV2
# Out:
#            NIK              BUSINESS_UNIT                        LOCATION  \
# 0    201700733  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 14
# 1    201801023  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 14
# 2    201903269  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 14
# 3    202104089  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 14
# 4    201600660  PT. HADJI KALLA (HOLDING)         HEAD OFFICE COKRO LT. 2
# ..         ...                        ...                             ...
# 523  201200662       PT. KALLA INTI KARSA                     WISMA KALLA
# 524  201100495       PT. KALLA INTI KARSA                     WISMA KALLA
# 525  200900350       PT. KALLA INTI KARSA                     WISMA KALLA
# 526  200800348       PT. KALLA INTI KARSA                     WISMA KALLA
# 527  200100421       PT. KALLA INTI KARSA                     WISMA KALLA
#
#                                     DEPARTMENT  \
# ...

# %%
mergedCSV2['potential']=(70/100*mergedCSV2['COMPETENCY'])+(30/100*mergedCSV2['LEARNING POINT'])

# %%
mergedCSV2
# Out:
#            NIK              BUSINESS_UNIT                        LOCATION  \
# 0    201700733  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 14
# 1    201801023  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 14
# 2    201903269  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 14
# 3    202104089  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 14
# 4    201600660  PT. HADJI KALLA (HOLDING)         HEAD OFFICE COKRO LT. 2
# ..         ...                        ...                             ...
# 523  201200662       PT. KALLA INTI KARSA                     WISMA KALLA
# 524  201100495       PT. KALLA INTI KARSA                     WISMA KALLA
# 525  200900350       PT. KALLA INTI KARSA                     WISMA KALLA
# 526  200800348       PT. KALLA INTI KARSA                     WISMA KALLA
# 527  200100421       PT. KALLA INTI KARSA                     WISMA KALLA
#
#                                     DEPARTMENT  \
# ...

# %%
#sum with additional point
mergedCSV2['total'] = mergedCSV2['potential']+mergedCSV2['PERFORMANCE']
#sum without additional point
mergedCSV2['total_without_add'] = mergedCSV2['potential']+mergedCSV2['perform_without_add']

# %%
best = mergedCSV2.loc[mergedCSV2['potential']>1.05]
best = mergedCSV2.loc[mergedCSV2['PERFORMANCE']>1.05]

# %%
best
# Out:
# Empty DataFrame
# Columns: [NIK, BUSINESS_UNIT, LOCATION, DEPARTMENT, JOB_POSITION, JOB_LEVEL, PK, PERFORMANCE, COMPETENCY, LEARNING POINT, Kerja Ibadah, Apresiasi, Lebih cepat, Aktif bersama, Cluster, perform_without_add, potential, total, total_without_add]
# Index: []

# %%
max_value = mergedCSV2['total'].max()

# %%
best_by_value = mergedCSV2.loc[mergedCSV2['total'] == max_value]
best_by_value
# Out:
#           NIK              BUSINESS_UNIT                       LOCATION  \
# 60  201800883  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 3
#
#                                 DEPARTMENT            JOB_POSITION  \
# 60  DATA & APPLICATION SOLUTION DEPARTMENT  ERP SUPPORT ASSOCIATES
#
#             JOB_LEVEL        PK  PERFORMANCE  COMPETENCY  LEARNING POINT  \
# 60  TECHNICAL LEADERS  0.970874     0.957895         1.0             1.0
#
#     Kerja Ibadah  Apresiasi  Lebih cepat  Aktif bersama  Cluster  \
# 60           1.0   0.982759     0.982759       0.982143        2
#
#     perform_without_add  potential     total  total_without_add
# 60             1.417392        1.0  1.957895           2.417392

# %%
sec_best = mergedCSV2.loc[mergedCSV2['potential']>1.04]
sec_best = mergedCSV2.loc[mergedCSV2['PERFORMANCE']>0.94]
sec_best
# Out:
#            NIK              BUSINESS_UNIT                        LOCATION  \
# 0    201700733  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 14
# 1    201801023  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 14
# 3    202104089  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 14
# 4    201600660  PT. HADJI KALLA (HOLDING)         HEAD OFFICE COKRO LT. 2
# 5    199700087  PT. HADJI KALLA (HOLDING)  HEAD OFFICE WISMA KALLA LT. 14
# ..         ...                        ...                             ...
# 509  201100512       PT. KALLA INTI KARSA                     HEAD OFFICE
# 513  200000200       PT. KALLA INTI KARSA                     WISMA KALLA
# 522  202003946       PT. KALLA INTI KARSA                     WISMA KALLA
# 523  201200662       PT. KALLA INTI KARSA                     WISMA KALLA
# 525  200900350       PT. KALLA INTI KARSA                     WISMA KALLA
#
#                                       DEPARTMENT  \
# ...
